# %%
import numpy as np
import pandas as pd
from collections import namedtuple, defaultdict
import os
import pickle
import sys
import csv 
import cv2
import matplotlib.pyplot as plt
from math import sqrt

# %%
def getErrors(dots, grountruth):
    errors = []
    for i, sealion in enumerate(sealion_types):
        gt = grountruth[sealion].get_values()[0]
        detected = len(dots[i])
        errors.append(detected - gt)
    return errors

# %%
def merge(dotsA, dotsB, errorsA, errorsB):
    mergedDots = []
    mergedErrors = []
    for i, sealion in enumerate(sealion_types): 
        if np.abs(errorsA[i]) <= np.abs(errorsB[i]):
            mergedDots.append(dotsA[i])
            mergedErrors.append(errorsA[i])
        else:
            mergedDots.append(dotsB[i])
            mergedErrors.append(errorsB[i])
    return mergedDots, mergedErrors

# %%
def compare(dotsA, dotsB):
    differences = []
    for i, _ in enumerate(sealion_types):
        differences.append(compareCoords(dotsA[i], dotsB[i]))
    return differences

# %%
def compareCoords(coordsA, coordsB):
    threshold = 3*3+3*3
    distances = np.zeros((len(coordsA), len(coordsB)))

    for a, cA in enumerate(coordsA):
        for b, cB in enumerate(coordsB):
            dx = cA[0] - cB[0]
            dy = cA[1] - cB[1]
            distances[a,b] = dx*dx + dy*dy
    
    mi = min(len(coordsA), len(coordsB))
    ma = max(len(coordsA), len(coordsB))
    umatchedA = set(range(len(coordsA)))
    umatchedB = set(range(len(coordsB)))
    mapping = dict()

    for i in range(mi):
        best = np.argmin(distances.ravel())
        best_row = best // len(coordsB)
        best_col = best % len(coordsB)
        if distances[best_row, best_col] < threshold:
            mapping[best_col] = best_row
            distances[best_row, :] = 1e12
            distances[:, best_col] = 1e12
            umatchedA.remove(best_row)
            umatchedB.remove(best_col)
        else:
            break
    
    matched = len(mapping)
    unmatched = ma - matched
    if len(umatchedA) + len(umatchedB) != 0:
        print("Unmatched points: ")
        if umatchedA:
            print("From A: ")
            for i in umatchedA:
                print(coordsA[i])
        if umatchedB:
            print("From B: ")
            for i in umatchedB:
                print(coordsB[i])
    return unmatched

# %%
df = pd.read_csv("../data/sealion/correct_coordinates.csv")

# %%
sealion_types = ["adult_males", 
    "subadult_males",
    "adult_females",
    "juveniles",
    "pups"]

# %%
sealion_index = dict()
for i, s in enumerate(sealion_types):
    sealion_index[s] = i

# %%
dotsC = dict()

# %%
def populate_dots(r):
    filename = r["filename"]
    train_id, _ = os.path.splitext(filename)
    train_id = int(train_id)
    x, y = r["x_coord"], r["y_coord"]
    x, y = int(round(x)), int(round(y))
    index = sealion_index[r["category"]]
    
    if train_id not in dotsC:
        dotsC[train_id] = [[], [], [], [], []]
    dotsC[train_id][index].append((x, y))

# %%
df.head()
# Out:
#    Unnamed: 0 filename  y_coord  x_coord       category
# 0           0    0.jpg     31.0   4238.0           pups
# 1           1    0.jpg     41.0   4240.0  adult_females
# 2           2    0.jpg     59.0   4722.0      juveniles
# 3           3    0.jpg     74.0   3833.0  adult_females
# 4           4    0.jpg     80.0   2756.0           pups

# %%
_ = df.apply(populate_dots, axis=1)

# %%
for train_id, dots in dotsC.items():
    with open("../data/sealion/TrainDotsB/{}C.pkl".format(train_id), "wb") as pfile:
        pickle.dump(dots, pfile, pickle.HIGHEST_PROTOCOL)

# %%
def get_train_id(filename):
    directory, basename = os.path.split(filename)
    train_id, ext = os.path.splitext(basename)
    return int(train_id)

# %%
def reprocess_all(train_ids=None):
    train_dir = "/home/lowik/sealion/data/sealion/Train/"
    dotted_dir = "/home/lowik/sealion/data/sealion/TrainDotted/"
    mask_dir = "/home/lowik/sealion/data/sealion/TrainMask/"
    debug_dir = "/home/lowik/sealion/data/sealion/TrainDebug/"
    dots_dir = "/home/lowik/sealion/data/sealion/TrainDotsB/"
    os.makedirs(debug_dir, exist_ok=True)
    os.makedirs(dots_dir, exist_ok=True)
    df = pd.read_csv(os.path.join(train_dir, "train.csv"))
    train_id_with_errors = []
    train_id_no_diff = []
    train_id_with_diff = []
    train_id_ok = []
    total_errors = dict()
    files_to_process = [filename for filename in os.listdir(train_dir) if filename.endswith("jpg")]
    for filename in files_to_process:
        train_id = get_train_id(filename)
        if train_ids is None or train_id in train_ids:
            #im_bgr = cv2.imread(os.path.join(train_dir, filename))
            im_dotted_bgr = cv2.imread(os.path.join(dotted_dir, filename))
            #im_mask = cv2.imread(os.path.join(mask_dir, filename), cv2.IMREAD_GRAYSCALE)
            
            
            with open(os.path.join(dots_dir, str(train_id) + ".pkl"), "rb") as ofile:
                    dotsA = pickle.load(ofile)
                
            if os.path.exists(os.path.join(dots_dir, str(train_id) + "C.pkl")):
                with open(os.path.join(dots_dir, str(train_id) + "C.pkl"), "rb") as ofile:
                    dotsB = pickle.load(ofile)
            else:
                dotsB = [[],[],[],[],[]]
            
            grountruth = df[df.train_id==int(train_id)]
            errorsA = getErrors(dotsA, grountruth)
            errorsB = getErrors(dotsB, grountruth)
            
            difference = compare(dotsA, dotsB)
            if np.sum(np.abs(difference)) == 0:
                print("[{i}] - No Difference A vs B".format(i=train_id))
                train_id_no_diff.append(train_id)
            else:
                print("[{i}] - Difference A vs B: {d}".format(i=train_id, d=difference))
                train_id_with_diff.append(train_id)
            
            mergeDots, mergeErrors = merge(dotsA, dotsB, errorsA, errorsB)
            sumErrors = np.sum(np.abs(mergeErrors))

            im_draw = draw_detected(im_dotted_bgr, mergeDots)
            cv2.imwrite(os.path.join(debug_dir, str(train_id) + "_merged.jpg"), im_draw)
            total_errors[train_id] = sumErrors
            if sumErrors > 0:
                train_id_with_errors.append(train_id)
                print("[{i}] - Total errors: {total} - {err}".format(i=train_id, total=sumErrors, err=mergeErrors))
            else:
                train_id_ok.append(train_id)
                print("[{i}] - ok".format(i=train_id))

            # Save dots
            with open(os.path.join(dots_dir, str(train_id) + "_merged.pkl"), "wb") as ofile:
                pickle.dump(mergeDots, ofile, pickle.HIGHEST_PROTOCOL)
    return train_id_with_errors, train_id_ok, train_id_no_diff, train_id_with_diff, total_errors

# %%
def draw_detected(im, dots):
    im_draw = im.copy()
    n = 5
    colors_rgb = [(1, 7, 244), (243, 17, 242), (5, 41, 79), (177, 54, 26), (26, 171, 43)]
    for i, centroids in enumerate(dots):
        for c in centroids:
            center = (int(round(c[0])), int(round(c[1])))
            cv2.circle(im_draw, center, 9, colors_rgb[i], 2)
    return im_draw

# %%
train_id_with_errors, train_id_ok, train_id_no_diff, train_id_with_diff, total_errors = reprocess_all()
# Out:
# [866] - No Difference A vs B
# [866] - ok
# [867] - No Difference A vs B
# [867] - ok
# [868] - No Difference A vs B
# [868] - ok
# [869] - Difference A vs B: [2, 3, 0, 0, 0]
# [869] - ok
# [87] - Difference A vs B: [0, 0, 1, 0, 0]
# [87] - ok
# [870] - No Difference A vs B
# [870] - ok
# [871] - No Difference A vs B
# [871] - Total errors: 7 - [0, 0, -3, 0, -4]
# [872] - No Difference A vs B
# [872] - ok
# [873] - No Difference A vs B
# [873] - Total errors: 1 - [0, 0, 0, -1, 0]
# [874] - No Difference A vs B
# [874] - ok
# [875] - No Difference A vs B
# [875] - ok
# [876] - No Difference A vs B
# [876] - ok
# [877] - No Difference A vs B
# [877] - ok
# [878] - No Difference A vs B
# [878] - Total errors: 1 - [0, -1, 0, 0, 0]
# [879] - No Difference A vs B
# [879] - ok
# [88] - No Difference A vs B
# [88] - ok
# [880] - No Difference A vs B
# [880] - ok
# [881] - Difference A vs B: [1, 0, 4, 0, 0]
# [881] - Total errors: 1 - [0, 0, 0, -1, 0]
# [882] - Difference A vs B: [2, 4, 5, 16, 0]
# [882] - Total errors: 1 - [0, 0, -1, 0, 0]
# [883] - No Difference A vs B
# [883] - ok
# [884] - No Difference A vs B
# [884] - ok
# [885] - No Difference A vs B
# [885] - ok
# [886] - Difference A vs B: [0, 0, 1, 0, 0]
# [886] - ok
# [887] - No Difference A vs B
# [887] - ok
# [888] - No Difference A vs B
# [888] - ok
# [889] - Difference A vs B: [2, 0, 0, 0, 0]
# [889] - Total errors: 3 - [-1, -1, 0, 0, -1]
# [89] - Difference A vs B: [0, 1, 0, 0, 0]
# [89] - Total errors: 2 - [-1, 0, -1, 0, 0]
# [890] - No Difference A vs B
# [890] - ok
# [891] - No Difference A vs B
# [891] - ok
# [892] - No Difference A vs B
# [892] - ok
# [893] - No Difference A vs B
# [893] - ok
# [894] - No Difference A vs B
# [894] - ok
# [895] - No Difference A vs B
# [895] - ok
# [896] - No Difference A vs B
# [896] - ok
# [897] - No Difference A vs B
# [897] - ok
# [898] - No Difference A vs B
# [898] - ok
# [899] - No Difference A vs B
# [899] - Total errors: 7 - [2, -1, 3, 1, 0]
# [9] - Difference A vs B: [0, 0, 2, 1, 0]
# [9] - Total errors: 113 - [-4, -1, -62, -35, -11]
# [90] - No Difference A vs B
# [90] - ok
# [900] - No Difference A vs B
# [900] - Total errors: 1 - [0, 0, -1, 0, 0]
# [901] - Difference A vs B: [3, 11, 123, 31, 0]
# [901] - ok
# [902] - No Difference A vs B
# [902] - ok
# [903] - No Difference A vs B
# [903] - Total errors: 54 - [-4, -5, -30, -14, -1]
# [904] - No Difference A vs B
# [904] - ok
# [592] - ok
# [593] - No Difference A vs B
# [593] - Total errors: 53 - [0, 0, 0, 53, 0]
# [594] - No Difference A vs B
# [594] - ok
# [595] - No Difference A vs B
# [595] - Total errors: 3 - [0, 0, -2, -1, 0]
# [596] - No Difference A vs B
# [596] - ok
# [597] - No Difference A vs B
# [597] - ok
# [598] - No Difference A vs B
# [598] - Total errors: 6 - [-2, -4, 0, 0, 0]
# [599] - No Difference A vs B
# [599] - ok
# [6] - No Difference A vs B
# [6] - ok
# [60] - No Difference A vs B
# [60] - ok
# [600] - No Difference A vs B
# [600] - ok
# [601] - No Difference A vs B
# [601] - ok
# [602] - No Difference A vs B
# [602] - ok
# [603] - No Difference A vs B
# [603] - ok
# [604] - Difference A vs B: [0, 0, 0, 1, 0]
# [604] - Total errors: 1 - [0, -1, 0, 0, 0]
# [605] - Difference A vs B: [4, 6, 2, 5, 0]
# [605] - ok
# [606] - No Difference A vs B
# [606] - Total errors: 1 - [-1, 0, 0, 0, 0]
# [607] - Difference A vs B: [0, 3, 14, 3, 0]
# [607] - Total errors: 4 - [-2, 0, -1, -1, 0]
# [608] - No Difference A vs B
# [608] - ok
# [609] - No Difference A vs B
# [609] - ok
# [61] - No Difference A vs B
# [61] - ok
# [610] - No Difference A vs B
# [610] - ok
# [611] - No Difference A vs B
# [611] - ok
# [612] - No Difference A vs B
# [612] - ok
# [613] - No Difference A vs B
# [613] - ok
# [614] - Difference A vs B: [1, 0, 5, 10, 0]
# [614] - ok
# [615] - No Difference A vs B
# [615] - ok
# [616] - No Difference A vs B
# [616] - ok
# [617] - No Difference A vs B
# [617] - ok
# [618] - No Difference A vs B
# [618] - ok
# [619] - No Difference A vs B
# [619] - Total errors: 1 - [0, 0, 0, -1, 0]
# [62] - No Difference A vs B
# [62] - Total errors: 1 - [0, 0, -1, 0, 0]
# [620] - No Difference A vs B
# [620] - ok
# [621] - Difference A vs B: [10, 10, 53, 36, 30]
# [621] - Total errors: 7 - [-5, -2, 0, 0, 0]
# [622] - No Difference A vs B
# [622] - ok
# [623] - No Difference A vs B
# [623] - ok
# [624] - No Difference A vs B
# [624] - ok
# [625] - No Difference A vs B
# [625] - ok
# [626] - No Difference A vs B
# [626] - ok
# [627] - No Difference A vs B
# [627] - ok
# [628] - No Difference A vs B
# [628] - ok
# [629] - Difference A vs B: [0, 0, 0, 0, 1]
# [629] - Total errors: 6 - [-3, -3, 0, 0, 0]
# [63] - No Difference A vs B
# [63] - Total errors: 1 - [0, 0, 0, 0, -1]
# [630] - No Difference A vs B
# [630] - ok
# [631] - No Difference A vs B
# [631] - ok
# [632] - No Difference A vs B
# [632] - Total errors: 1 - [-1, 0, 0, 0, 0]
# [633] - No Difference A vs B
# [633] - Total errors: 2 - [0, 0, 0, 0, -2]
# [634] - No Difference A vs B
# [634] - ok
# [635] - No Difference A vs B
# [635] - ok
# [636] - No Difference A vs B
# [636] - ok
# [637] - No Difference A vs B
# [637] - ok
# [638] - Difference A vs B: [2, 2, 0, 0, 0]
# [468] - ok
# [469] - Difference A vs B: [0, 2, 8, 7, 0]
# [469] - ok
# [47] - No Difference A vs B
# [47] - Total errors: 2 - [0, -2, 0, 0, 0]
# [470] - No Difference A vs B
# [470] - ok
# [471] - No Difference A vs B
# [471] - ok
# [472] - No Difference A vs B
# [472] - ok
# [473] - No Difference A vs B
# [473] - Total errors: 3 - [0, 0, 0, 3, 0]
# [474] - No Difference A vs B
# [474] - ok
# [475] - Difference A vs B: [3, 6, 61, 85, 0]
# [475] - ok
# [476] - No Difference A vs B
# [476] - Total errors: 4 - [0, 0, -4, 0, 0]
# [477] - No Difference A vs B
# [477] - ok
# [478] - No Difference A vs B
# [478] - ok
# [479] - No Difference A vs B
# [479] - Total errors: 1 - [0, -1, 0, 0, 0]
# [48] - No Difference A vs B
# [48] - ok
# [480] - No Difference A vs B
# [480] - ok
# [481] - No Difference A vs B
# [481] - ok
# [482] - No Difference A vs B
# [482] - Total errors: 1 - [0, 0, 0, -1, 0]
# [483] - No Difference A vs B
# [483] - Total errors: 2 - [0, -1, 0, -1, 0]
# [484] - No Difference A vs B
# [484] - ok
# [485] - No Difference A vs B
# [485] - ok
# [486] - No Difference A vs B
# [486] - ok
# [487] - No Difference A vs B
# [487] - Total errors: 1 - [0, -1, 0, 0, 0]
# [488] - No Difference A vs B
# [488] - ok
# [489] - No Difference A vs B
# [489] - ok
# [49] - No Difference A vs B
# [49] - ok
# [490] - No Difference A vs B
# [490] - Total errors: 29 - [-6, -5, -14, -4, 0]
# [491] - No Difference A vs B
# [491] - ok
# [492] - No Difference A vs B
# [492] - Total errors: 1 - [0, -1, 0, 0, 0]
# [493] - No Difference A vs B
# [493] - ok
# [494] - No Difference A vs B
# [494] - ok
# [495] - Difference A vs B: [0, 0, 1, 0, 0]
# [495] - Total errors: 3 - [-3, 0, 0, 0, 0]
# [496] - No Difference A vs B
# [496] - ok
# [497] - No Difference A vs B
# [497] - ok
# [498] - No Difference A vs B
# [498] - ok
# [499] - No Difference A vs B
# [499] - Total errors: 8 - [-3, -3, -2, 0, 0]
# [5] - No Difference A vs B
# [5] - ok
# [50] - No Difference A vs B
# [50] - ok
# [500] - No Difference A vs B
# [500] - Total errors: 4 - [-2, 1, 0, -1, 0]
# [501] - No Difference A vs B
# [501] - ok
# [502] - No Difference A vs B
# [502] - ok
# [503] - No Difference A vs B
# [503] - ok
# [504] - No Difference A vs B
# [504] - ok
# [505] - No Difference A vs B
# [505] - Total errors: 2 - [0, -1, 0, -1, 0]
# [506] - No Difference A vs B
# [506] - ok
# [507] - No Difference A vs B
# [507] - Total errors: 88 - [-8, -6, -27, -47, 0]
# [508] - No Difference A vs B
# [508] - ok
# [509] - No Difference A vs B
# [509] - Total errors: 3 - [0, -1, -1, 0, -1]
# [51] - No Difference A vs B
# [51] - ok
# [510] - No Difference A vs B
# [510] - Total errors: 3 - [3, 0, 0, 0, 0]
# [511] - No Difference A vs B
# [511] - ok
# [512] - No Difference A vs B
# [512] - ok
# [135] - No Difference A vs B
# [135] - ok
# [136] - No Difference A vs B
# [136] - Total errors: 1 - [0, 0, 0, -1, 0]
# [137] - No Difference A vs B
# [137] - ok
# [138] - No Difference A vs B
# [138] - ok
# [139] - No Difference A vs B
# [139] - ok
# [14] - No Difference A vs B
# [14] - ok
# [140] - No Difference A vs B
# [140] - ok
# [141] - No Difference A vs B
# [141] - ok
# [142] - No Difference A vs B
# [142] - ok
# [143] - No Difference A vs B
# [143] - ok
# [144] - No Difference A vs B
# [144] - ok
# [145] - No Difference A vs B
# [145] - ok
# [146] - No Difference A vs B
# [146] - Total errors: 1 - [0, 0, -1, 0, 0]
# [147] - No Difference A vs B
# [147] - ok
# [148] - Difference A vs B: [0, 1, 0, 0, 0]
# [148] - Total errors: 1 - [0, 0, 0, -1, 0]
# [149] - No Difference A vs B
# [149] - ok
# [15] - No Difference A vs B
# [15] - Total errors: 7 - [0, 0, -2, -5, 0]
# [150] - No Difference A vs B
# [150] - ok
# [151] - No Difference A vs B
# [151] - Total errors: 47 - [-6, -4, -21, 0, -16]
# [152] - No Difference A vs B
# [152] - ok
# [153] - No Difference A vs B
# [153] - ok
# [154] - No Difference A vs B
# [154] - ok
# [155] - No Difference A vs B
# [155] - Total errors: 1 - [0, 0, 0, 0, -1]
# [156] - No Difference A vs B
# [156] - ok
# [157] - No Difference A vs B
# [157] - ok
# [158] - No Difference A vs B
# [158] - ok
# [159] - No Difference A vs B
# [159] - ok
# [16] - No Difference A vs B
# [16] - ok
# [160] - No Difference A vs B
# [160] - ok
# [161] - No Difference A vs B
# [161] - ok
# [162] - No Difference A vs B
# [162] - ok
# [163] - No Difference A vs B
# [163] - ok
# [164] - No Difference A vs B
# [164] - ok
# [165] - No Difference A vs B
# [165] - ok
# [166] - No Difference A vs B
# [166] - ok
# [167] - No Difference A vs B
# [167] - ok
# [168] - No Difference A vs B
# [168] - ok
# [169] - No Difference A vs B
# [169] - ok
# [17] - No Difference A vs B
# [17] - ok
# [170] - Difference A vs B: [1, 0, 0, 0, 0]
# [170] - Total errors: 2 - [0, 0, -1, 0, -1]
# [171] - No Difference A vs B
# [171] - ok
# [172] - No Difference A vs B
# [172] - ok
# [173] - No Difference A vs B
# [173] - ok
# [174] - Difference A vs B: [1, 0, 1, 0, 0]
# [174] - ok
# [175] - No Difference A vs B
# [175] - Total errors: 2 - [0, -1, 0, -1, 0]
# [176] - No Difference A vs B
# [176] - ok
# [177] - Difference A vs B: [0, 1, 0, 0, 0]
# [177] - ok
# [178] - No Difference A vs B
# [178] - Total errors: 3 - [0, 0, -1, -2, 0]
# [179] - No Difference A vs B
# [179] - Total errors: 2 - [-2, 0, 0, 0, 0]
# [18] - No Difference A vs B
# [18] - Total errors: 1 - [0, -1, 0, 0, 0]
# [180] - No Difference A vs B
# [180] - ok
# [181] - No Difference A vs B
# [181] - Total errors: 2 - [0, 0, -1, -1, 0]
# [182] - No Difference A vs B
# [182] - ok
# [183] - No Difference A vs B
# [183] - ok
# [184] - Difference A vs B: [6, 16, 0, 7, 0]
# [184] - Total errors: 19 - [0, 0, -19, 0, 0]
# [185] - No Difference A vs B
# [185] - ok
# [186] - Difference A vs B: [0, 0, 3, 0, 0]
# [186] - Total errors: 1 - [0, -1, 0, 0, 0]
# [187] - Difference A vs B: [0, 0, 1, 0, 0]
# [187] - Total errors: 2 - [-2, 0, 0, 0, 0]
# [188] - No Difference A vs B
# [188] - ok
# [189] - No Difference A vs B
# [189] - ok
# [19] - No Difference A vs B
# [19] - ok
# [190] - No Difference A vs B
# [190] - ok
# [191] - No Difference A vs B
# [191] - ok
# [192] - No Difference A vs B
# [192] - ok
# [193] - No Difference A vs B
# [193] - ok
# [194] - No Difference A vs B
# [194] - ok
# [195] - No Difference A vs B
# [195] - ok
# [196] - No Difference A vs B
# [196] - ok
# [197] - Difference A vs B: [0, 0, 1, 0, 0]
# [197] - ok
# [198] - No Difference A vs B
# [198] - ok
# [199] - No Difference A vs B
# [199] - ok
# [2] - No Difference A vs B
# [2] - Total errors: 2 - [0, 0, -1, -1, 0]
# [20] - No Difference A vs B
# [20] - ok
# [200] - No Difference A vs B
# [200] - ok
# [201] - No Difference A vs B
# [201] - ok
# [202] - No Difference A vs B
# [202] - ok
# [203] - No Difference A vs B
# [203] - ok
# [204] - No Difference A vs B
# [204] - ok
# [205] - No Difference A vs B
# [205] - ok

# %%
import operator

# %%
sorted_errors = sorted(total_errors.items(), key=operator.itemgetter(1))

# %%
sorted_errors[::-1]
# Out:
# [(34, 350),
#  (406, 122),
#  (9, 113),
#  (384, 92),
#  (507, 88),
#  (3, 85),
#  (767, 80),
#  (234, 73),
#  (7, 60),
#  (292, 58),
#  (66, 55),
#  (903, 54),
#  (712, 53),
#  (593, 53),
#  (909, 48),
#  (151, 47),
#  (21, 40),
#  (331, 34),
#  (97, 30),
#  (490, 29),
#  (811, 24),
#  (268, 22),
#  (529, 20),
#  (184, 19),
#  (81, 19),
#  (426, 16),
#  (857, 14),
#  (344, 12),
#  (905, 10),
#  (643, 9),
#  (587, 9),
#  (585, 8),
#  (516, 8),
#  (499, 8),
#  (899, 7),
#  (871, 7),
#  (837, 7),
#  (621, 7),
#  (412, 7),
#  (207, 7),
#  (129, 7),
#  (15, 7),
#  (918, 6),
#  (629, 6),
#  (598, 6),
#  (437, 6),
#  (67, 6),
#  (776, 5),
#  (751, 5),
#  (265, 5),
#  (105, 5),
#  (38, 5),
#  (941, 4),
#  (925, 4),
#  (910, 4),
#  (827, 4),
#  (750, 4),
#  (607, 4),
#  (500, 4),
#  (476, 4),
#  (421, 4),
#  (394, 4),
#  (297, 4),
#  (252, 4),
#  (215, 4),
#  (122, 4),
#  (83, 4),
#  (906, 3),
#  (889, 3),
#  (823, 3),
#  (781, 3),
#  (761, 3),
#  (759, 3),
#  (739, 3),
#  (724, 3),
#  (700, 3),
#  (595, 3),
#  (574, 3),
#  (571, 3),
#  (524, 3),
#  (510, 3),
#  (509, 3),
#  (495, 3),
#  (473, 3),
#  (409, 3),
#  (405, 3),
#  (398, 3),
#  (362, 3),
#  (359, 3),
#  (342, 3),
#  (240, 3),
#  (235, 3),
#  (178, 3),
#  (36, 3),
#  (917, 2),
#  (912, 2),
#  (865, 2),
#  (858, 2),
#  (806, 2),
#  (800, 2),
#  (795, 2),
#  (788, 2),
#  (763, 2),
#  (754, 2),
#  (732, 2),
#  (699, 2),
#  (686, 2),
#  (679, 2),
#  (675, 2),
#  (662, 2),
#  (633, 2),
#  (568, 2),
#  (555, 2),
#  (554, 2),
#  (505, 2),
#  (483, 2),
#  (467, 2),
#  (462, 2),
#  (433, 2),
#  (416, 2),
#  (395, 2),
#  (386, 2),
#  (383, 2),
#  (369, 2),
#  (365, 2),
#  (328, 2),
#  (293, 2),
#  (291, 2),
#  (218, 2),
#  (216, 2),
#  (214, 2),
#  (187, 2),
#  (181, 2),
#  (179, 2),
#  (175, 2),
#  (170, 2),
#  (134, 2),
#  (127, 2),
#  (99, 2),
#  (93, 2),
#  (89, 2),
#  (77, 2),
#  (47, 2),
#  (40, 2),
#  (11, 2),
#  (2, 2),
#  (937, 1),
#  (934, 1),
#  (933, 1),
#  (926, 1),
#  (924, 1),
#  (921, 1),
#  (900, 1),
#  (882, 1),
#  (881, 1),
#  (878, 1),
#  (873, 1),
#  (845, 1),
#  (840, 1),
#  (822, 1),
#  (814, 1),
#  (813, 1),
#  (805, 1),
#  (803, 1),
#  (798, 1),
#  (790, 1),
#  (779, 1),
#  (764, 1),
#  (748, 1),
#  (745, 1),
#  (744, 1),
#  (741, 1),
#  (729, 1),
#  (710, 1),
#  (707, 1),
#  (706, 1),
#  (698, 1),
#  (676, 1),
#  (655, 1),
#  (645, 1),
#  (632, 1),
#  (619, 1),
#  (606, 1),
#  (604, 1),
#  (577, 1),
#  (553, 1),
#  (552, 1),
#  (544, 1),
#  (543, 1),
#  (539, 1),
#  (538, 1),
#  (518, 1),
#  (492, 1),
#  (487, 1),
#  (482, 1),
#  (479, 1),
#  (465, 1),
#  (460, 1),
#  (441, 1),
#  (418, 1),
#  (410, 1),
#  (388, 1),
#  (375, 1),
#  (351, 1),
#  (338, 1),
#  (335, 1),
#  (330, 1),
#  (325, 1),
#  (323, 1),
#  (312, 1),
#  (309, 1),
#  (303, 1),
#  (299, 1),
#  (298, 1),
#  (290, 1),
#  (271, 1),
#  (258, 1),
#  (256, 1),
#  (242, 1),
#  (221, 1),
#  (211, 1),
#  (186, 1),
#  (155, 1),
#  (148, 1),
#  (146, 1),
#  (136, 1),
#  (110, 1),
#  (108, 1),
#  (91, 1),
#  (80, 1),
#  (73, 1),
#  (63, 1),
#  (62, 1),
#  (58, 1),
#  (52, 1),
#  (18, 1),
#  (13, 1),
#  (947, 0),
#  (946, 0),
#  (945, 0),
#  (944, 0),
#  (943, 0),
#  (942, 0),
#  (940, 0),
#  (939, 0),
#  (938, 0),
#  (936, 0),
#  (935, 0),
#  (932, 0),
#  (931, 0),
#  (930, 0),
#  (929, 0),
#  (928, 0),
#  (927, 0),
#  (923, 0),
#  (922, 0),
#  (920, 0),
#  (919, 0),
#  (916, 0),
#  (915, 0),
#  (914, 0),
#  (913, 0),
#  (911, 0),
#  (908, 0),
#  (907, 0),
#  (904, 0),
#  (902, 0),
#  (901, 0),
#  (898, 0),
#  (897, 0),
#  (896, 0),
#  (895, 0),
#  (894, 0),
#  (893, 0),
#  (892, 0),
#  (891, 0),
#  (890, 0),
#  (888, 0),
#  (887, 0),
#  (886, 0),
#  (885, 0),
#  (884, 0),
#  (883, 0),
#  (880, 0),
#  (879, 0),
#  (877, 0),
#  (876, 0),
#  (875, 0),
#  (874, 0),
#  (872, 0),
#  (870, 0),
#  (869, 0),
#  (868, 0),
#  (867, 0),
#  (866, 0),
#  (864, 0),
#  (863, 0),
#  (862, 0),
#  (861, 0),
#  (860, 0),
#  (859, 0),
#  (856, 0),
#  (855, 0),
#  (854, 0),
#  (853, 0),
#  (852, 0),
#  (851, 0),
#  (850, 0),
#  (849, 0),
#  (848, 0),
#  (847, 0),
#  (846, 0),
#  (844, 0),
#  (843, 0),
#  (842, 0),
#  (841, 0),
#  (839, 0),
#  (838, 0),
#  (836, 0),
#  (835, 0),
#  (834, 0),
#  (833, 0),
#  (832, 0),
#  (831, 0),
#  (830, 0),
#  (829, 0),
#  (828, 0),
#  (826, 0),
#  (825, 0),
#  (824, 0),
#  (821, 0),
#  (820, 0),
#  (819, 0),
#  (818, 0),
#  (817, 0),
#  (816, 0),
#  (815, 0),
#  (812, 0),
#  (810, 0),
#  (809, 0),
#  (808, 0),
#  (807, 0),
#  (804, 0),
#  (802, 0),
#  (801, 0),
#  (799, 0),
#  (797, 0),
#  (796, 0),
#  (794, 0),
#  (793, 0),
#  (792, 0),
#  (791, 0),
#  (789, 0),
#  (787, 0),
#  (786, 0),
#  (785, 0),
#  (784, 0),
#  (783, 0),
#  (782, 0),
#  (780, 0),
#  (778, 0),
#  (777, 0),
#  (775, 0),
#  (774, 0),
#  (773, 0),
#  (772, 0),
#  (771, 0),
#  (770, 0),
#  (769, 0),
#  (768, 0),
#  (766, 0),
#  (765, 0),
#  (762, 0),
#  (760, 0),
#  (758, 0),
#  (757, 0),
#  (756, 0),
#  (755, 0),
#  (753, 0),
#  (752, 0),
#  (749, 0),
#  (747, 0),
#  (746, 0),
#  (743, 0),
#  (742, 0),
#  (740, 0),
#  (738, 0),
#  (737, 0),
#  (736, 0),
#  (735, 0),
#  (734, 0),
#  (733, 0),
#  (731, 0),
#  (730, 0),
#  (728, 0),
#  (727, 0),
#  (726, 0),
#  (725, 0),
#  (723, 0),
#  (722, 0),
#  (721, 0),
#  (720, 0),
#  (719, 0),
#  (718, 0),
#  (717, 0),
#  (716, 0),
#  (715, 0),
#  (714, 0),
#  (713, 0),
#  (711, 0),
#  (709, 0),
#  (708, 0),
#  (705, 0),
#  (704, 0),
#  (703, 0),
#  (702, 0),
#  (701, 0),
#  (697, 0),
#  (696, 0),
#  (695, 0),
#  (694, 0),
#  (693, 0),
#  (692, 0),
#  (691, 0),
#  (690, 0),
#  (689, 0),
#  (688, 0),
#  (687, 0),
#  (685, 0),
#  (684, 0),
#  (683, 0),
#  (682, 0),
#  (681, 0),
#  (680, 0),
#  (678, 0),
#  (677, 0),
#  (674, 0),
#  (673, 0),
#  (672, 0),
#  (671, 0),
#  (670, 0),
#  (669, 0),
#  (668, 0),
#  (667, 0),
#  (666, 0),
#  (665, 0),
#  (664, 0),
#  (663, 0),
#  (661, 0),
#  (660, 0),
#  (659, 0),
#  (658, 0),
#  (657, 0),
#  (656, 0),
#  (654, 0),
#  (653, 0),
#  (652, 0),
#  (651, 0),
#  (650, 0),
#  (649, 0),
#  (648, 0),
#  (647, 0),
#  (646, 0),
#  (644, 0),
#  (642, 0),
#  (641, 0),
#  (640, 0),
#  (639, 0),
#  (638, 0),
#  (637, 0),
#  (636, 0),
#  (635, 0),
#  (634, 0),
#  (631, 0),
#  (630, 0),
#  (628, 0),
#  (627, 0),
#  (626, 0),
#  (625, 0),
#  (624, 0),
#  (623, 0),
#  (622, 0),
#  (620, 0),
#  (618, 0),
#  (617, 0),
#  (616, 0),
#  (615, 0),
#  (614, 0),
#  (613, 0),
#  (612, 0),
#  (611, 0),
#  (610, 0),
#  (609, 0),
#  (608, 0),
#  (605, 0),
#  (603, 0),
#  (602, 0),
#  (601, 0),
#  (600, 0),
#  (599, 0),
#  (597, 0),
#  (596, 0),
#  (594, 0),
#  (592, 0),
#  (591, 0),
#  (590, 0),
#  (589, 0),
#  (588, 0),
#  (586, 0),
#  (584, 0),
#  (583, 0),
#  (582, 0),
#  (581, 0),
#  (580, 0),
#  (579, 0),
#  (578, 0),
#  (576, 0),
#  (575, 0),
#  (573, 0),
#  (572, 0),
#  (570, 0),
#  (569, 0),
#  (567, 0),
#  (566, 0),
#  (565, 0),
#  (564, 0),
#  (563, 0),
#  (562, 0),
#  (561, 0),
#  (560, 0),
#  (559, 0),
#  (558, 0),
#  (557, 0),
#  (556, 0),
#  (551, 0),
#  (550, 0),
#  (549, 0),
#  (548, 0),
#  (547, 0),
#  (546, 0),
#  (545, 0),
#  (542, 0),
#  (541, 0),
#  (540, 0),
#  (537, 0),
#  (536, 0),
#  (535, 0),
#  (534, 0),
#  (533, 0),
#  (532, 0),
#  (531, 0),
#  (530, 0),
#  (528, 0),
#  (527, 0),
#  (526, 0),
#  (525, 0),
#  (523, 0),
#  (522, 0),
#  (521, 0),
#  (520, 0),
#  (519, 0),
#  (517, 0),
#  (515, 0),
#  (514, 0),
#  (513, 0),
#  (512, 0),
#  (511, 0),
#  (508, 0),
#  (506, 0),
#  (504, 0),
#  (503, 0),
#  (502, 0),
#  (501, 0),
#  (498, 0),
#  (497, 0),
#  (496, 0),
#  (494, 0),
#  (493, 0),
#  (491, 0),
#  (489, 0),
#  (488, 0),
#  (486, 0),
#  (485, 0),
#  (484, 0),
#  (481, 0),
#  (480, 0),
#  (478, 0),
#  (477, 0),
#  (475, 0),
#  (474, 0),
#  (28, 0),
#  (27, 0),
#  (26, 0),
#  (25, 0),
#  (24, 0),
#  (23, 0),
#  (22, 0),
#  (20, 0),
#  (19, 0),
#  (17, 0),
#  (16, 0),
#  (14, 0),
#  (12, 0),
#  (10, 0),
#  (8, 0),
#  (6, 0),
#  (5, 0),
#  (4, 0),
#  (1, 0),
#  (0, 0)]

# %%
df_c = pd.read_csv("../data/sealion/correct_coordinates.csv")

# %%
diff_with_C = []
for train_id in train_id_with_diff:
    if os.path.exists("/home/lowik/sealion/data/sealion/TrainDotsB/{}C.pkl".format(train_id)):
        diff_with_C.append(train_id)

# %%
len(diff_with_C)
# Out:
# 79

# %%
sorted(diff_with_C)
# Out:
# [58,
#  66,
#  80,
#  87,
#  110,
#  112,
#  122,
#  127,
#  148,
#  170,
#  174,
#  177,
#  186,
#  187,
#  197,
#  235,
#  240,
#  259,
#  270,
#  275,
#  277,
#  291,
#  292,
#  310,
#  323,
#  328,
#  330,
#  338,
#  359,
#  361,
#  368,
#  383,
#  395,
#  403,
#  416,
#  418,
#  420,
#  431,
#  437,
#  452,
#  462,
#  495,
#  526,
#  529,
#  538,
#  566,
#  578,
#  584,
#  587,
#  604,
#  629,
#  645,
#  658,
#  671,
#  684,
#  699,
#  704,
#  715,
#  741,
#  742,
#  744,
#  759,
#  773,
#  791,
#  803,
#  804,
#  822,
#  827,
#  828,
#  845,
#  881,
#  886,
#  889,
#  912,
#  914,
#  920,
#  924,
#  939,
#  941]

# %%
df = pd.read_csv(os.path.join("/home/lowik/sealion/data/sealion/Train/", "train.csv"))

# %%
c_is_good = [58, 66, 87, 110, 122, 148, 187, 235, 259, 270, 275, 277, 292, 310, 323, 328, 330, 338, 359, 368, 383, 395, 403, ]

# %%
def check(train_id):
    im = cv2.imread("../data/sealion/TrainDotted/{}.jpg".format(train_id))
    with open("../data/sealion/TrainDotsB/{}.pkl".format(train_id), "rb") as pfile:
        dots = pickle.load(pfile)
    with open("../data/sealion/TrainDotsB/{}C.pkl".format(train_id), "rb") as pfile:
        dotsC = pickle.load(pfile)
    im_draw = draw_detected(im.copy(), dots)
    im_drawC = draw_detected(im.copy(), dotsC)
    cv2.imwrite("../data/check.jpg", im_draw)
    cv2.imwrite("../data/checkC.jpg", im_drawC)
    compare(dots, dotsC)
    print(" ".join([str(len(d)) for d in dots]))    
    print(" ".join([str(len(d)) for d in dotsC]))    
    print(df[df.train_id == train_id])

# %%
check(418)
# Out:
# Unmatched points:
# From A:
# (1622, 1032)
# (1715, 1151)
# (1510, 1229)
# 10 6 139 150 0
# 10 6 136 150 0
#      train_id  adult_males  subadult_males  adult_females  juveniles  pups
# 418       418           11               6            139        150     0

# %%
with open("../data/sealion/TrainDotsB/58.pkl", "rb") as pfile:
    dots = pickle.load(pfile)

# %%
print(" ".join([str(len(d)) for d in dots]))
# Out:
# 37 17 143 71 145

# %%
df[df.train_id == 58]
# Out:
#     train_id  adult_males  subadult_males  adult_females  juveniles  pups
# 58        58           36              17            143         71   145
