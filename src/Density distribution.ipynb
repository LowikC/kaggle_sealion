# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dmap = np.sum(np.load("../data/sealion/TrainDensity/872_2.npz")["dmap"], axis=-1)

# %%
plt.imshow(dmap)

# %%
plt.hist(np.sqrt(dmap.ravel()), bins=30, log=True)
# Out:
# (array([  1.77705600e+06,   6.68600000e+04,   5.64720000e+04,
#           5.74880000e+04,   5.13070000e+04,   4.89380000e+04,
#           3.95680000e+04,   2.89270000e+04,   1.94560000e+04,
#           1.50130000e+04,   1.14300000e+04,   8.73900000e+03,
#           7.05400000e+03,   5.86600000e+03,   4.69200000e+03,
#           3.44600000e+03,   3.19300000e+03,   2.47300000e+03,
#           1.90700000e+03,   1.46400000e+03,   1.39600000e+03,
#           1.05300000e+03,   7.52000000e+02,   5.81000000e+02,
#           4.31000000e+02,   2.60000000e+02,   1.95000000e+02,
#           1.25000000e+02,   8.50000000e+01,   6.60000000e+01]),
#  array([  0.00000000e+00,   6.60656175e-05,   1.32131235e-04,
#           1.98196853e-04,   2.64262470e-04,   3.30328088e-04,
#           3.96393705e-04,   4.62459323e-04,   5.28524940e-04,
#           5.94590558e-04,   6.60656175e-04,   7.26721793e-04,
#           7.92787410e-04,   8.58853028e-04,   9.24918645e-04,
# ...

# %%
plt.hist(np.exp(-1 + dmap.ravel()), bins=30)
# Out:
# (array([  1.77720900e+06,   6.68500000e+04,   5.64420000e+04,
#           5.75780000e+04,   5.13020000e+04,   4.89060000e+04,
#           3.96100000e+04,   2.88380000e+04,   1.94380000e+04,
#           1.49830000e+04,   1.14470000e+04,   8.69900000e+03,
#           7.06000000e+03,   5.84500000e+03,   4.68500000e+03,
#           3.44200000e+03,   3.20500000e+03,   2.46200000e+03,
#           1.89300000e+03,   1.46800000e+03,   1.38900000e+03,
#           1.05100000e+03,   7.51000000e+02,   5.78000000e+02,
#           4.34000000e+02,   2.57000000e+02,   1.95000000e+02,
#           1.25000000e+02,   8.50000000e+01,   6.60000000e+01]),
#  array([ 0.36787945,  0.36790378,  0.36792811,  0.36795243,  0.36797676,
#          0.36800109,  0.36802542,  0.36804974,  0.36807407,  0.3680984 ,
#          0.36812273,  0.36814705,  0.36817138,  0.36819571,  0.36822004,
#          0.36824436,  0.36826869,  0.36829302,  0.36831735,  0.36834168,
# ...
