# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import pandas as pd
from collections import namedtuple, defaultdict
import os
import pickle
import sys
import operator
import glob
import csv 
from math import sqrt

import PIL
from PIL import Image, ImageDraw, ImageFilter

import skimage
import skimage.io
import skimage.measure

import shapely
import shapely.geometry
from shapely.geometry import Polygon
# %matplotlib inline

# %%
SOURCEDIR = os.path.join('../data/','sealion')

DATADIR = '.'

VERBOSITY = namedtuple('VERBOSITY', ['QUITE', 'NORMAL', 'VERBOSE', 'DEBUG'])(0,1,2,3)

# %%
SeaLionCoord = namedtuple('SeaLionCoord', ['tid', 'cls', 'x', 'y'])

# %%
class SeaLionData(object):
    
    def __init__(self, sourcedir=SOURCEDIR, datadir=DATADIR, verbosity=VERBOSITY.NORMAL):
        self.sourcedir = sourcedir
        self.datadir = datadir
        self.verbosity = verbosity
        
        self.cls_nb = 5
        
        self.cls_names = (
            'adult_males',
            'subadult_males',
            'adult_females',
            'juveniles',
            'pups',
            'NOT_A_SEA_LION')
            
        self.cls = namedtuple('ClassIndex', self.cls_names)(*range(0,6))
    
        # backported from @bitsofbits. Average actual color of dot centers.
        self.cls_colors = (
            (243,8,5),          # red
            (244,8,242),        # magenta
            (87,46,10),         # brown 
            (25,56,176),        # blue
            (38,174,21),        # green
            )
    
            
        self.dot_radius = 3
        
        self.train_nb = 947
        
        self.test_nb = 18636
       
        self.paths = {
            # Source paths
            'sample'     : os.path.join(sourcedir, 'sample_submission.csv'),
            'counts'     : os.path.join(sourcedir, 'Train', 'train.csv'),
            'train'      : os.path.join(sourcedir, 'Train', '{tid}.jpg'),
            'dotted'     : os.path.join(sourcedir, 'TrainDotted', '{tid}.jpg'),
            'test'       : os.path.join(sourcedir, 'Test', '{tid}.jpg'),
            # Data paths
            'coords'     : os.path.join(datadir, 'coords.csv'),  
            }
        
        # From MismatchedTrainImages.txt
        self.bad_train_ids = (
            3, 7, 9, 21, 30, 34, 71, 81, 89, 97, 151, 184, 215, 234, 242, 
            268, 290, 311, 331, 344, 380, 384, 406, 421, 469, 475, 490, 499, 
            507, 530, 531, 605, 607, 614, 621, 638, 644, 687, 712, 721, 767, 
            779, 781, 794, 800, 811, 839, 840, 869, 882, 901, 903, 905, 909, 
            913, 927, 946)
            
        self._counts = None

        
    @property
    def trainshort_ids(self):
        return (0,1,2,4,5,6,8,10)  # Trainshort1
        #return range(41,51)         # Trainshort2
        
    @property 
    def train_ids(self):
        """List of all valid train ids"""
        tids = range(0, self.train_nb)
        tids = list(set(tids) - set(self.bad_train_ids) )  # Remove bad ids
        tids.sort()
        return tids
                    
    @property 
    def test_ids(self):
        return range(0, self.test_nb)
    
    def path(self, name, **kwargs):
        """Return path to various source files"""
        path = self.paths[name].format(**kwargs)
        return path        

    @property
    def counts(self) :
        """A map from train_id to list of sea lion class counts"""
        if self._counts is None :
            counts = {}
            fn = self.path('counts')
            with open(fn) as f:
                f.readline()
                for line in f:
                    tid_counts = list(map(int, line.split(',')))
                    counts[tid_counts[0]] = tid_counts[1:]
            self._counts = counts
        return self._counts

    def rmse(self, tid_counts) :
        true_counts = self.counts
        
        error = np.zeros(shape=[5] )
        
        for tid in tid_counts:
            true_counts = self.counts[tid]
            obs_counts = tid_counts[tid]
            diff = np.asarray(true_counts) - np.asarray(obs_counts)
            error += diff*diff
        #print(error)
        error /= len(tid_counts)
        rmse = np.sqrt(error).sum() / 5
        return rmse 
        

    def load_train_image(self, train_id, border=0, mask=False):
        """Return image as numpy array
         
        border -- add a black border of this width around image
        mask -- If true mask out masked areas from corresponding dotted image
        """
        img = self._load_image('train', train_id, border)
        if mask :
            # The masked areas are not uniformly black, presumable due to 
            # jpeg compression artifacts
            dot_img = self._load_image('dotted', train_id, border).astype(np.uint16).sum(axis=-1)
            img = np.copy(img)
            img[dot_img<40] = 0
        return img
   

    def load_dotted_image(self, train_id, border=0):
        return self._load_image('dotted', train_id, border)
 
 
    def load_test_image(self, test_id, border=0):    
        return self._load_image('test', test_id, border)


    def _load_image(self, itype, tid, border=0) :
        fn = self.path(itype, tid=tid)
        img = np.asarray(Image.open(fn))
        if border :
            height, width, channels = img.shape
            bimg = np.zeros( shape=(height+border*2, width+border*2, channels), dtype=np.uint8)
            bimg[border:-border, border:-border, :] = img
            img = bimg
        return img
    

    def coords(self, train_id):
        """Extract coordinates of dotted sealions and return list of SeaLionCoord objects)"""
        
        # Empirical constants
        MIN_DIFFERENCE = 16
        MIN_AREA = 9
        MAX_AREA = 100
        MAX_AVG_DIFF = 50
        MAX_COLOR_DIFF = 32
       
        src_img = np.asarray(self.load_train_image(train_id, mask=True), dtype = np.float)
        dot_img = np.asarray(self.load_dotted_image(train_id), dtype = np.float)

        img_diff = np.abs(src_img-dot_img)
        
        # Detect bad data. If train and dotted images are very different then somethings wrong.
        avg_diff = img_diff.sum() / (img_diff.shape[0] * img_diff.shape[1])
        if avg_diff > MAX_AVG_DIFF: return {}
        
        img_diff = np.max(img_diff, axis=-1)   
           
        img_diff[img_diff<MIN_DIFFERENCE] = 0
        img_diff[img_diff>=MIN_DIFFERENCE] = 255

        sealions = []
        
        for cls, color in enumerate(self.cls_colors):
            # color search backported from @bitsofbits.
            color_array = np.array(color)[None, None, :]
            has_color = np.sqrt(np.sum(np.square(dot_img * (img_diff > 0)[:,:,None] - color_array), axis=-1)) < MAX_COLOR_DIFF 
            contours = skimage.measure.find_contours(has_color.astype(float), 0.5)
            
            if self.verbosity == VERBOSITY.DEBUG :
                print()
                fn = 'diff_{}_{}.png'.format(train_id,cls)
                print('Saving train/dotted difference: {}'.format(fn))
                Image.fromarray((has_color*255).astype(np.uint8)).save(fn)

            for cnt in contours :
                p = Polygon(shell=cnt)
                area = p.area 
                if(area > MIN_AREA and area < MAX_AREA) :
                    y, x= p.centroid.coords[0] # DANGER : skimage and cv2 coordinates transposed?
                    x = int(round(x))
                    y = int(round(y))
                    sealions.append( SeaLionCoord(train_id, cls, x, y) )
                
        if self.verbosity >= VERBOSITY.VERBOSE :
            counts = [0,0,0,0,0]
            for c in sealions :
                counts[c.cls] +=1
            print()
            print('train_id','true_counts','counted_dots', 'difference', sep='\t')   
            true_counts = self.counts[train_id]
            print(train_id, true_counts, counts, np.array(true_counts) - np.array(counts) , sep='\t' )
          
        if self.verbosity == VERBOSITY.DEBUG :
            img = np.copy(sld.load_dotted_image(train_id))
            r = self.dot_radius
            dy,dx,c = img.shape
            for tid, cls, cx, cy in sealions :                    
                for x in range(cx-r, cx+r+1) : img[cy, x, :] = 255
                for y in range(cy-r, cy+r+1) : img[y, cx, :] = 255    
            fn = 'cross_{}.png'.format(train_id)
            print('Saving crossed dots: {}'.format(fn))
            Image.fromarray(img).save(fn)
     
        return self.convert(sealions)
        

    def save_coords(self, train_ids=None): 
        if train_ids is None: train_ids = self.train_ids
        fn = self.path('coords')
        self._progress('Saving sealion coordinates to {}'.format(fn))
        with open(fn, 'w') as csvfile:
            writer =csv.writer(csvfile)
            writer.writerow( SeaLionCoord._fields )
            for tid in train_ids :
                self._progress()
                for coord in self.coords(tid):
                    writer.writerow(coord)
        self._progress('done')
        
    def load_coords(self):
        fn = self.path('coords')
        self._progress('Loading sea lion coordinates from {}'.format(fn))
        with open(fn) as f:
            f.readline()
            return [SeaLionCoord(*[int(n) for n in line.split(',')]) for line in f]

    
            
    def save_sea_lion_chunks(self, coords, chunksize=128):
        self._progress('Saving image chunks...')
        self._progress('\n', verbosity=VERBOSITY.VERBOSE)
        
        last_tid = -1
        
        for tid, cls, x, y in coords :
            if tid != last_tid:
                img = self.load_train_image(tid, border=chunksize//2, mask=True)
                last_tid = tid

            fn = 'chunk_{tid}_{cls}_{x}_{y}_{size}.png'.format(size=chunksize, tid=tid, cls=cls, x=x, y=y)
            self._progress(' Saving '+fn, end='\n', verbosity=VERBOSITY.VERBOSE)
            Image.fromarray( img[y:y+chunksize, x:x+chunksize, :]).save(fn)
            self._progress()
        self._progress('done')
        
            
    def _progress(self, string=None, end=' ', verbosity=VERBOSITY.NORMAL):
        if self.verbosity < verbosity: return
        if not string :
            print('.', end='')
        elif string == 'done':
            print(' done') 
        else:
            print(string, end=end)
        sys.stdout.flush()

    def convert(self, slcoord):
        dots = defaultdict(list)
        for c in slcoord:
            name = self.cls_names[c.cls]
            dots[name].append((c.x, c.y))
        return dots
# end SeaLionData

# %% [markdown]
#     red: adult males
#     magenta: subadult males
#     brown: adult females
#     blue: juveniles
#     green: pups

# %%
HSVColor = namedtuple("HSVColor", ["hue_offset", "hue_min", "hue_max", "sat_min", "sat_max", "val_min", "val_max"])

# %%
sealion_types = ["adult_males", 
    "subadult_males",
    "adult_females",
    "juveniles",
    "pups"]

# %%
dot_colors = {
    "adult_males": HSVColor(90, 80, 100, 210, 255, 160, 255),     # red
    "subadult_males": HSVColor(0, 145, 155, 230, 255, 220, 255),  # magenta
    "adult_females": HSVColor(0, 7, 23, 130, 255, 50, 105),      # brown
    "juveniles": HSVColor(0, 103, 123, 155, 240, 115, 200),       # blue
    "pups": HSVColor(0, 47, 67, 200, 255, 148, 200)               # green
}

# %%
def get_diff_mask(im_bgr, im_dotted_bgr):
    """ Return a boolean mask with the difference between the dotted and non-dotted image.
    """
    diff_dotted_bgr = cv2.absdiff(im_bgr, im_dotted_bgr)
    diff_dotted_gray = np.max(diff_dotted_bgr, axis=2)
    
    # Find the best threshold: check how many pixels turn white for the next threshold.
    variation_by_threshold = np.diff(np.cumsum(np.bincount(diff_dotted_gray.ravel())), 1)
    
    threshold_diff = 50
    for i in range(variation_by_threshold.shape[0] - 1, 0, -1):
        if variation_by_threshold[i] > 110:
            threshold_diff = i
            break

    diff_dotted_mask = diff_dotted_gray > threshold_diff
    return diff_dotted_mask, diff_dotted_gray

# %%
def detect_dots(im_bgr, im_dotted_bgr, mask_u8, dot_colors, train_id = 0):    
    # Erode mask to avoid issue on the edges of the mask
    radius = 5
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (radius, radius))
    mask_eroded_u8 = cv2.erode(mask_u8, kernel)
    _, mask_eroded_u8 = cv2.threshold(mask_eroded_u8, 1, 255, cv2.THRESH_BINARY)
    
    # Apply mask on both image
    im_bgr_masked = cv2.bitwise_and(im_bgr, im_bgr, mask=mask_eroded_u8)
    im_dotted_bgr_masked = cv2.bitwise_and(im_dotted_bgr, im_dotted_bgr, mask=mask_eroded_u8)
    
    # Compute the diff between dotted and non-dotted images. 
    diff_dotted_mask, diff_dotted_gray = get_diff_mask(im_bgr_masked, im_dotted_bgr_masked)
    diff_dotted_mask_u8 = (diff_dotted_mask * 255).astype(np.uint8)
    total_diff = np.sum(diff_dotted_mask_u8)
    if total_diff > 2000 * 40 * 40:
        print("[{i}] - Error in diff image".format(i=train_id))
        return {}, diff_dotted_mask_u8, diff_dotted_gray
    
    # Find the dot for each type of sealion.
    n_labels, im_labels, stats, centroids = cv2.connectedComponentsWithStats(diff_dotted_mask_u8, connectivity=8)

    min_size = 3*3
    max_size = 15*15
    ratio_min = 0.5
    ratio_max = 2.0
    dots = defaultdict(list)
    for blob_id, stat in enumerate(stats):
        ratio = stat[2]/(1.0 * stat[3] + 1)
        if min_size < stat[4] < max_size and ratio_min < ratio < ratio_max:
            half_size = 1
            center = int(round(centroids[blob_id][0])), int(round(centroids[blob_id][1]))
            if center[0] < half_size or center[1] < half_size or center[0] > im_dotted_bgr.shape[1] - half_size or center[1] > im_dotted_bgr.shape[0] - half_size:
                print("Error coord")
                continue
            dot_bgr = im_dotted_bgr[center[1] - half_size:center[1] + half_size + 1,
                                    center[0] - half_size:center[0] + half_size + 1, :]
            dot_hsv = cv2.cvtColor(dot_bgr, cv2.COLOR_BGR2HSV)
            hue = dot_hsv[:,:,0]
            sat = dot_hsv[:,:,1]
            val = dot_hsv[:,:,2]
            sat_median = np.median(sat)
            val_median = np.median(val)
            n_nn = 0
            for sealion, color in dot_colors.items():
                hue_off = (hue.astype(np.uint16) + color.hue_offset) % 180
                hue_median = np.median(hue_off)
                if color.hue_min <= hue_median <= color.hue_max and \
                    color.val_min <= val_median <= color.val_max and \
                    color.sat_min <= sat_median <= color.sat_max:
                        dots[sealion].append(centroids[blob_id])
                else:
                    n_nn += 1
            if n_nn == len(dot_colors):
                continue
                #print("Not found: ", train_id, center, hue, np.median(hue), sat_median, val_median)
                    

    return dots, diff_dotted_mask_u8, diff_dotted_gray

# %%
def draw_detected(im, dots):
    im_draw = im.copy()
    n = 5
    colors = plt.cm.rainbow(np.linspace(0, 1, n))
    colors_rgb = [(int(c[0]), int(c[1]), int(c[2])) for c in colors * 255]
    for i, (sealion, centroids) in enumerate(dots.items()):
        for c in centroids:
            center = (int(round(c[0])), int(round(c[1])))
            cv2.circle(im_draw, center, 9, colors_rgb[i], 1)
            cv2.circle(im_draw, center, 1, colors_rgb[i], -1)
    return im_draw

# %%
def print_numbers(train_id, dots):
    ns = []
    for sealion in sealion_types:
        n = 0 if sealion not in dots else len(dots[sealion])
        ns.append(n)
    print("[{i}] - {ns}".format(i=train_id, ns=ns))

# %%
def get_train_id(filename):
    directory, basename = os.path.split(filename)
    train_id, ext = os.path.splitext(basename)
    return int(train_id)

# %%
def merge(dotsA, dotsB, errorsA, errorsB):
    mergedDots = dict()
    mergedErrors = []
    for i, sealion in enumerate(sealion_types): 
        if np.abs(errorsA[i]) <= np.abs(errorsB[i]):
            if sealion in dotsA:
                mergedDots[sealion] = dotsA[sealion]
                mergedErrors.append(errorsA[i])
        else:
            mergedDots[sealion] = dotsB[sealion]
            mergedErrors.append(errorsB[i])
    return mergedDots, mergedErrors

# %%
def getErrors(dots, grountruth):
    errors = []
    for sealion in sealion_types:
        gt = grountruth[sealion].get_values()[0]
        detected = 0 if sealion not in dots else len(dots[sealion])
        errors.append(detected - gt)
    return errors

# %%
def compare(dotsA, dotsB):
    differences = []
    for k in sealion_types:
        if k in dotsA:
            if k not in dotsB:
                differences.append(len(dotsA[k]))
            else:
                differences.append(compareCoords(dotsA[k], dotsB[k]))
        elif k in dotsB:
            differences.append(len(dotsB[k]))
        else:
            differences.append(0)
    return differences

# %%
def compareCoords(coordsA, coordsB):
    threshold = 3*3+3*3
    distances = np.zeros((len(coordsA), len(coordsB)))
    for a, cA in enumerate(coordsA):
        for b, cB in enumerate(coordsB):
            dx = cA[0] - cB[0]
            dy = cA[1] - cB[1]
            distances[a,b] = dx*dx + dy*dy
    
    mi = min(len(coordsA), len(coordsB))
    ma = max(len(coordsA), len(coordsB))
    
    mapping = dict()
    for i in range(mi):
        best = np.argmin(distances.ravel())
        best_row = best // len(coordsB)
        best_col = best % len(coordsB)
        if distances[best_row, best_col] < threshold:
            mapping[best_col] = best_row
            distances[best_row, :] = 99999
            distances[:, best_col] = 99999
        else:
            break
    
    matched = len(mapping)
    unmatched = ma - matched
    return unmatched

# %%
a = [(0, 0), (10, 10), (20, 20), (30, 30)]
b = [(11, 11), (1, 1), (32, 28), (20, 19)]
c = [(15, 5), (1, 1), (32, 24), (20, 19), (550, 54)]

# %%
compareCoords(a, a)
# Out:
# 0

# %%
compareCoords(a, b)
# Out:
# 0

# %%
compareCoords(a, c)
# Out:
# 3

# %%
def process_all(train_ids=None):
    train_dir = "/home/lowik/sealion/data/sealion/Train/"
    dotted_dir = "/home/lowik/sealion/data/sealion/TrainDotted/"
    mask_dir = "/home/lowik/sealion/data/sealion/TrainMask/"
    debug_dir = "/home/lowik/sealion/data/sealion/TrainDebug/"
    dots_dir = "/home/lowik/sealion/data/sealion/TrainDots/"
    os.makedirs(debug_dir, exist_ok=True)
    os.makedirs(dots_dir, exist_ok=True)
    df = pd.read_csv(os.path.join(train_dir, "train.csv"))
    train_id_with_errors = []
    train_id_no_diff = []
    train_id_with_diff = []
    train_id_ok = []
    files_to_process = [filename for filename in os.listdir(train_dir) if filename.endswith("jpg")]
    sld = SeaLionData()
    for filename in files_to_process:
        train_id = get_train_id(filename)
        if train_ids is None or train_id in train_ids:
            im_bgr = cv2.imread(os.path.join(train_dir, filename))
            im_dotted_bgr = cv2.imread(os.path.join(dotted_dir, filename))
            im_mask = cv2.imread(os.path.join(mask_dir, filename), cv2.IMREAD_GRAYSCALE)
            
            dotsA, diff_dotted_mask_u8, diff_dotted_gray = detect_dots(im_bgr, im_dotted_bgr, im_mask, dot_colors, train_id)
            dotsB = sld.coords(train_id)
            
            with open(os.path.join(dots_dir, str(train_id) + "A.pkl"), "wb") as ofile:
                pickle.dump(dotsA, ofile, pickle.HIGHEST_PROTOCOL)
                
            with open(os.path.join(dots_dir, str(train_id) + "B.pkl"), "wb") as ofile:
                pickle.dump(dotsB, ofile, pickle.HIGHEST_PROTOCOL)
            
            grountruth = df[df.train_id==int(train_id)]
            errorsA = getErrors(dotsA, grountruth)
            errorsB = getErrors(dotsB, grountruth)
            
            difference = compare(dotsA, dotsB)
            if np.sum(np.abs(difference)) == 0:
                print("[{i}] - No Difference A vs B".format(i=train_id))
                train_id_no_diff.append(train_id)
            else:
                print("[{i}] - Difference A vs B: {d}".format(i=train_id, d=difference))
                train_id_with_diff.append(train_id)
            
            mergeDots, mergeErrors = merge(dotsA, dotsB, errorsA, errorsB)
            sumErrors = np.sum(np.abs(mergeErrors))
            
            im_draw = draw_detected(im_dotted_bgr, mergeDots)
            cv2.imwrite(os.path.join(debug_dir, str(train_id) + ".jpg"), im_draw)
            if sumErrors > 0:
                train_id_with_errors.append(train_id)
                print("[{i}] - Total errors: {total} - {err}".format(i=train_id, total=sumErrors, err=mergeErrors))
            else:
                train_id_ok.append(train_id)
                print("[{i}] - ok".format(i=train_id))

            # Save dots
            with open(os.path.join(dots_dir, str(train_id) + ".pkl"), "wb") as ofile:
                pickle.dump(mergeDots, ofile, pickle.HIGHEST_PROTOCOL)
    return train_id_with_errors, train_id_ok, train_id_no_diff, train_id_with_diff

# %%
train_id_with_errors, train_id_ok, train_id_no_diff, train_id_with_diff = process_all()

# %%
def reprocess_all(train_ids=None):
    train_dir = "/home/lowik/sealion/data/sealion/Train/"
    dotted_dir = "/home/lowik/sealion/data/sealion/TrainDotted/"
    mask_dir = "/home/lowik/sealion/data/sealion/TrainMask/"
    debug_dir = "/home/lowik/sealion/data/sealion/TrainDebug/"
    dots_dir = "/home/lowik/sealion/data/sealion/TrainDots/"
    os.makedirs(debug_dir, exist_ok=True)
    os.makedirs(dots_dir, exist_ok=True)
    df = pd.read_csv(os.path.join(train_dir, "train.csv"))
    train_id_with_errors = []
    train_id_no_diff = []
    train_id_with_diff = []
    train_id_ok = []
    files_to_process = [filename for filename in os.listdir(train_dir) if filename.endswith("jpg")]
    sld = SeaLionData()
    for filename in files_to_process:
        train_id = get_train_id(filename)
        if train_ids is None or train_id in train_ids:
            #im_bgr = cv2.imread(os.path.join(train_dir, filename))
            #im_dotted_bgr = cv2.imread(os.path.join(dotted_dir, filename))
            #im_mask = cv2.imread(os.path.join(mask_dir, filename), cv2.IMREAD_GRAYSCALE)
            
            with open(os.path.join(dots_dir, str(train_id) + "A.pkl"), "rb") as ofile:
                dotsA = pickle.load(ofile)
                
            with open(os.path.join(dots_dir, str(train_id) + "B.pkl"), "rb") as ofile:
                dotsB = pickle.load(ofile)
            
            grountruth = df[df.train_id==int(train_id)]
            errorsA = getErrors(dotsA, grountruth)
            errorsB = getErrors(dotsB, grountruth)
            
            difference = compare(dotsA, dotsB)
            if np.sum(np.abs(difference)) == 0:
                print("[{i}] - No Difference A vs B".format(i=train_id))
                train_id_no_diff.append(train_id)
            else:
                print("[{i}] - Difference A vs B: {d}".format(i=train_id, d=difference))
                train_id_with_diff.append(train_id)
            
            mergeDots, mergeErrors = merge(dotsA, dotsB, errorsA, errorsB)
            sumErrors = np.sum(np.abs(mergeErrors))
            
            #im_draw = draw_detected(im_dotted_bgr, mergeDots)
            #cv2.imwrite(os.path.join(debug_dir, str(train_id) + ".jpg"), im_draw)
            if sumErrors > 0:
                train_id_with_errors.append(train_id)
                print("[{i}] - Total errors: {total} - {err}".format(i=train_id, total=sumErrors, err=mergeErrors))
            else:
                train_id_ok.append(train_id)
                print("[{i}] - ok".format(i=train_id))

            # Save dots
            #with open(os.path.join(dots_dir, str(train_id) + ".pkl"), "wb") as ofile:
            #    pickle.dump(mergeDots, ofile, pickle.HIGHEST_PROTOCOL)
    return train_id_with_errors, train_id_ok, train_id_no_diff, train_id_with_diff

# %%
train_id_with_errors, train_id_ok, train_id_no_diff, train_id_with_diff = reprocess_all()
# Out:
# [866] - No Difference A vs B
# [866] - ok
# [867] - No Difference A vs B
# [867] - ok
# [868] - No Difference A vs B
# [868] - ok
# [869] - Difference A vs B: [2, 3, 0, 0, 0]
# [869] - ok
# [87] - No Difference A vs B
# [87] - Total errors: 1 - [0, 0, -1, 0]
# [870] - No Difference A vs B
# [870] - ok
# [871] - Difference A vs B: [1, 1, 123, 16, 172]
# [871] - Total errors: 7 - [0, 0, -3, 0, -4]
# [872] - No Difference A vs B
# [872] - ok
# [873] - No Difference A vs B
# [873] - Total errors: 1 - [0, 0, -1]
# [874] - Difference A vs B: [0, 0, 0, 0, 1]
# [874] - ok
# [875] - No Difference A vs B
# [875] - ok
# [876] - No Difference A vs B
# [876] - ok
# [877] - No Difference A vs B
# [877] - ok
# [878] - No Difference A vs B
# [878] - ok
# [879] - Difference A vs B: [0, 0, 0, 2, 0]
# [879] - ok
# [88] - No Difference A vs B
# [88] - ok
# [880] - No Difference A vs B
# [880] - ok
# [881] - Difference A vs B: [0, 0, 97, 30, 114]
# [881] - Total errors: 1 - [0, 0, 0, -1, 0]
# [882] - Difference A vs B: [2, 4, 5, 16, 0]
# [882] - Total errors: 1 - [0, 0, -1, 0]
# [883] - No Difference A vs B
# [883] - ok
# [884] - No Difference A vs B
# [884] - ok
# [885] - No Difference A vs B
# [885] - ok
# [886] - No Difference A vs B
# [886] - ok
# [887] - No Difference A vs B
# [887] - ok
# [888] - No Difference A vs B
# [888] - ok
# [889] - Difference A vs B: [2, 0, 0, 0, 0]
# [889] - Total errors: 2 - [-1, 0, 0, -1]
# [89] - Difference A vs B: [0, 1, 0, 0, 0]
# [89] - ok
# [890] - No Difference A vs B
# [890] - ok
# [891] - No Difference A vs B
# [891] - ok
# [892] - Difference A vs B: [0, 0, 50, 0, 68]
# [892] - ok
# [893] - No Difference A vs B
# [893] - ok
# [894] - Difference A vs B: [0, 0, 0, 4, 0]
# [894] - ok
# [895] - No Difference A vs B
# [895] - ok
# [896] - No Difference A vs B
# [896] - ok
# [897] - No Difference A vs B
# [897] - ok
# [898] - No Difference A vs B
# [898] - ok
# [899] - No Difference A vs B
# [899] - Total errors: 7 - [2, -1, 3, 1]
# [9] - Difference A vs B: [0, 0, 2, 1, 0]
# [9] - Total errors: 97 - [-62, -35]
# [90] - No Difference A vs B
# [90] - ok
# [900] - Difference A vs B: [31, 2, 657, 25, 529]
# [900] - Total errors: 1 - [0, 0, -1, 0, 0]
# [901] - No Difference A vs B
# [901] - ok
# [902] - No Difference A vs B
# [902] - ok
# [903] - No Difference A vs B
# [903] - ok
# [904] - No Difference A vs B
# [904] - ok
# [905] - Difference A vs B: [0, 1, 0, 0, 0]
# [905] - Total errors: 1 - [-1]
# [906] - Difference A vs B: [0, 0, 1, 0, 0]
# [906] - Total errors: 3 - [0, -1, -2, 0, 0]
# [907] - No Difference A vs B
# [907] - ok
# [908] - No Difference A vs B
# [908] - ok
# [909] - No Difference A vs B
# [909] - ok
# [91] - Difference A vs B: [7, 0, 128, 1, 156]
# [91] - Total errors: 1 - [0, 0, 0, -1]
# [910] - No Difference A vs B
# [910] - Total errors: 4 - [0, 0, -4]
# [911] - No Difference A vs B
# [911] - ok
# [912] - Difference A vs B: [30, 2, 246, 13, 205]
# [912] - Total errors: 2 - [0, 0, 2, 0, 0]
# [913] - Difference A vs B: [0, 0, 142, 0, 0]
# [913] - ok
# [914] - No Difference A vs B
# [914] - Total errors: 1 - [0, 0, 0, -1]
# [915] - No Difference A vs B
# [915] - ok
# [916] - No Difference A vs B
# [916] - ok
# [917] - Difference A vs B: [0, 0, 0, 2, 0]
# [917] - Total errors: 2 - [0, 0, -1, -1]
# [918] - Difference A vs B: [0, 0, 0, 1, 0]
# [918] - Total errors: 6 - [0, 0, -3, 0, 3]
# [919] - Difference A vs B: [0, 0, 0, 3, 0]
# [919] - ok
# [92] - No Difference A vs B
# [92] - ok
# [920] - Difference A vs B: [6, 0, 270, 172, 2]
# [920] - Total errors: 1 - [0, 0, 0, -1, 0]
# [921] - No Difference A vs B
# [921] - Total errors: 1 - [0, 0, 1]
# [922] - No Difference A vs B
# [922] - ok
# [923] - Difference A vs B: [0, 0, 64, 0, 0]
# [923] - ok
# [924] - Difference A vs B: [0, 0, 60, 1, 50]
# [924] - Total errors: 1 - [0, 0, 0, 0, -1]
# [925] - No Difference A vs B
# [925] - Total errors: 4 - [0, -1, 0, -3]
# [926] - No Difference A vs B
# [926] - Total errors: 1 - [0, 0, -1]
# [927] - Difference A vs B: [1, 0, 17, 5, 0]
# [927] - ok
# [928] - No Difference A vs B
# [928] - ok
# [929] - No Difference A vs B
# [929] - ok
# [93] - Difference A vs B: [5, 0, 120, 83, 40]
# [93] - Total errors: 2 - [-1, 0, 0, 1, 0]
# [930] - No Difference A vs B
# [930] - ok
# [931] - No Difference A vs B
# [931] - ok
# [932] - Difference A vs B: [0, 0, 0, 2, 0]
# [932] - ok
# [933] - No Difference A vs B
# [933] - Total errors: 1 - [0, 0, 0, -1, 0]
# [934] - No Difference A vs B
# [934] - Total errors: 1 - [0, 0, 0, -1]
# [935] - No Difference A vs B
# [935] - ok
# [936] - No Difference A vs B
# [936] - ok
# [937] - No Difference A vs B
# [937] - Total errors: 1 - [0, -1, 0, 0]
# [938] - No Difference A vs B
# [938] - ok
# [939] - Difference A vs B: [0, 0, 1, 0, 0]
# [939] - ok
# [94] - No Difference A vs B
# [94] - ok
# [940] - No Difference A vs B
# [940] - ok
# [941] - No Difference A vs B
# [941] - Total errors: 5 - [-1, 0, -1, -1, -2]
# [942] - No Difference A vs B
# [942] - ok
# [943] - No Difference A vs B
# [943] - ok
# [944] - No Difference A vs B
# [944] - ok
# [945] - No Difference A vs B
# [945] - ok
# [946] - Difference A vs B: [3, 1, 34, 33, 0]
# [946] - ok
# [947] - No Difference A vs B
# [947] - ok
# [95] - Difference A vs B: [0, 0, 0, 6, 0]
# [95] - ok
# [96] - Difference A vs B: [0, 0, 4, 0, 0]
# [96] - ok
# [97] - No Difference A vs B
# [97] - ok
# [98] - No Difference A vs B
# [98] - ok
# [99] - No Difference A vs B
# [99] - Total errors: 2 - [0, 0, -2, 0]
# [756] - No Difference A vs B
# [756] - ok
# [757] - No Difference A vs B
# [757] - ok
# [758] - No Difference A vs B
# [758] - ok
# [759] - Difference A vs B: [1, 0, 43, 2, 93]
# [759] - Total errors: 3 - [0, -3, 0, 0, 0]
# [76] - No Difference A vs B
# [76] - ok
# [760] - No Difference A vs B
# [760] - ok
# [761] - Difference A vs B: [0, 0, 2, 0, 0]
# [761] - Total errors: 3 - [0, 0, 0, -3]
# [762] - No Difference A vs B
# [762] - ok
# [763] - No Difference A vs B
# [763] - Total errors: 2 - [0, -2]
# [764] - No Difference A vs B
# [764] - Total errors: 1 - [0, 0, 0, 0, -1]
# [765] - No Difference A vs B
# [765] - ok
# [766] - No Difference A vs B
# [766] - ok
# [767] - No Difference A vs B
# [767] - ok
# [768] - No Difference A vs B
# [768] - ok
# [769] - Difference A vs B: [0, 0, 11, 0, 111]
# [769] - ok
# [77] - Difference A vs B: [0, 0, 51, 2, 74]
# [77] - Total errors: 2 - [-1, 0, 0, 0, -1]
# [770] - No Difference A vs B
# [770] - ok
# [771] - Difference A vs B: [0, 0, 2, 2, 0]
# [771] - ok
# [772] - No Difference A vs B
# [772] - ok
# [773] - Difference A vs B: [24, 6, 201, 5, 138]
# [773] - ok
# [774] - Difference A vs B: [20, 0, 139, 12, 114]
# [774] - ok
# [775] - No Difference A vs B
# [775] - ok
# [776] - No Difference A vs B
# [776] - Total errors: 5 - [5, 0, 0, 0, 0]
# [777] - No Difference A vs B
# [777] - ok
# [778] - No Difference A vs B
# [778] - ok
# [779] - No Difference A vs B
# [779] - ok
# [78] - Difference A vs B: [1, 2, 5, 0, 5]
# [78] - ok
# [780] - No Difference A vs B
# [780] - ok
# [781] - Difference A vs B: [0, 0, 1, 0, 0]
# [781] - Total errors: 3 - [0, 0, 0, -3]
# [782] - No Difference A vs B
# [782] - ok
# [783] - No Difference A vs B
# [783] - ok
# [784] - Difference A vs B: [3, 1, 185, 184, 0]
# [784] - ok
# [785] - Difference A vs B: [23, 1, 212, 18, 229]
# [785] - ok
# [786] - No Difference A vs B
# [786] - ok
# [787] - No Difference A vs B
# [787] - ok
# [788] - No Difference A vs B
# [788] - Total errors: 2 - [-1, -1, 0, 0]
# [789] - No Difference A vs B
# [789] - ok
# [79] - No Difference A vs B
# [79] - ok
# [790] - No Difference A vs B
# [790] - Total errors: 1 - [0, 0, -1, 0, 0]
# [791] - Difference A vs B: [0, 0, 2, 0, 0]
# [791] - ok
# [792] - Difference A vs B: [0, 0, 1, 0, 0]
# [792] - ok
# [793] - No Difference A vs B
# [793] - ok
# [794] - Difference A vs B: [0, 0, 62, 0, 0]
# [794] - ok
# [795] - No Difference A vs B
# [795] - Total errors: 1 - [0, -1]
# [796] - No Difference A vs B
# [796] - ok
# [797] - No Difference A vs B
# [797] - ok
# [798] - No Difference A vs B
# [798] - ok
# [799] - No Difference A vs B
# [799] - ok
# [8] - No Difference A vs B
# [8] - ok
# [80] - No Difference A vs B
# [80] - Total errors: 1 - [-1, 0]
# [800] - No Difference A vs B
# [800] - ok
# [801] - No Difference A vs B
# [801] - ok
# [802] - No Difference A vs B
# [802] - ok
# [803] - Difference A vs B: [13, 3, 258, 40, 122]
# [803] - Total errors: 2 - [-1, 0, 1, 0, 0]
# [804] - No Difference A vs B
# [804] - Total errors: 1 - [0, 0, 0, -1]
# [805] - No Difference A vs B
# [805] - Total errors: 1 - [0, 0, 0, 0, -1]
# [806] - No Difference A vs B
# [806] - Total errors: 2 - [0, -1, 0, -1, 0]
# [807] - No Difference A vs B
# [807] - ok
# [808] - No Difference A vs B
# [808] - ok
# [809] - Difference A vs B: [0, 0, 0, 4, 0]
# [809] - ok
# [81] - No Difference A vs B
# [81] - ok
# [810] - No Difference A vs B
# [810] - ok
# [811] - No Difference A vs B
# [811] - ok
# [812] - No Difference A vs B
# [812] - ok
# [813] - No Difference A vs B
# [813] - Total errors: 1 - [0, 0, 0, -1]
# [814] - No Difference A vs B
# [814] - Total errors: 1 - [0, 0, -1]
# [815] - No Difference A vs B
# [815] - ok
# [816] - Difference A vs B: [1, 0, 1, 23, 0]
# [816] - ok
# [817] - No Difference A vs B
# [817] - ok
# [818] - No Difference A vs B
# [818] - ok
# [819] - No Difference A vs B
# [819] - ok
# [82] - No Difference A vs B
# [82] - ok
# [820] - No Difference A vs B
# [820] - ok
# [821] - No Difference A vs B
# [821] - ok
# [822] - Difference A vs B: [8, 2, 171, 9, 210]
# [822] - Total errors: 1 - [0, 0, 0, -1, 0]
# [823] - No Difference A vs B
# [823] - Total errors: 3 - [0, -3, 0, 0]
# [824] - No Difference A vs B
# [824] - ok
# [825] - No Difference A vs B
# [825] - ok
# [826] - No Difference A vs B
# [826] - ok
# [827] - No Difference A vs B
# [827] - Total errors: 4 - [-4, 0, 0]
# [828] - Difference A vs B: [0, 0, 2, 0, 0]
# [828] - ok
# [829] - Difference A vs B: [0, 0, 1, 0, 0]
# [829] - ok
# [83] - No Difference A vs B
# [83] - Total errors: 4 - [0, 0, 1, -3]
# [830] - Difference A vs B: [0, 0, 0, 2, 0]
# [830] - ok
# [831] - No Difference A vs B
# [831] - ok
# [832] - No Difference A vs B
# [832] - ok
# [833] - Difference A vs B: [5, 1, 162, 9, 214]
# [833] - ok
# [834] - No Difference A vs B
# [834] - ok
# [835] - No Difference A vs B
# [835] - ok
# [836] - No Difference A vs B
# [836] - ok
# [837] - No Difference A vs B
# [837] - ok
# [838] - No Difference A vs B
# [838] - ok
# [839] - Difference A vs B: [1, 1, 0, 1, 0]
# [839] - ok
# [84] - No Difference A vs B
# [84] - ok
# [840] - Difference A vs B: [2, 2, 47, 14, 0]
# [840] - Total errors: 1 - [0, -1, 0, 0]
# [841] - No Difference A vs B
# [841] - ok
# [842] - No Difference A vs B
# [842] - ok
# [843] - No Difference A vs B
# [843] - ok
# [844] - No Difference A vs B
# [844] - ok
# [845] - Difference A vs B: [0, 0, 0, 2, 0]
# [845] - Total errors: 1 - [0, 0, 0, -1]
# [846] - No Difference A vs B
# [846] - ok
# [847] - Difference A vs B: [6, 0, 163, 16, 151]
# [847] - ok
# [848] - No Difference A vs B
# [848] - ok
# [849] - No Difference A vs B
# [849] - ok
# [85] - No Difference A vs B
# [85] - ok
# [850] - No Difference A vs B
# [850] - ok
# [851] - No Difference A vs B
# [851] - ok
# [852] - No Difference A vs B
# [852] - ok
# [853] - No Difference A vs B
# [853] - ok
# [854] - No Difference A vs B
# [854] - ok
# [855] - No Difference A vs B
# [855] - ok
# [856] - Difference A vs B: [0, 0, 1, 1, 0]
# [856] - ok
# [857] - No Difference A vs B
# [857] - ok
# [858] - No Difference A vs B
# [858] - Total errors: 2 - [-2, 0, 0, 0]
# [859] - No Difference A vs B
# [859] - ok
# [86] - No Difference A vs B
# [86] - ok
# [860] - No Difference A vs B
# [860] - ok
# [861] - No Difference A vs B
# [861] - ok
# [862] - No Difference A vs B
# [862] - ok
# [863] - No Difference A vs B
# [863] - ok
# [864] - Difference A vs B: [2, 0, 51, 0, 171]
# [864] - ok
# [865] - No Difference A vs B
# [865] - ok
# [646] - No Difference A vs B
# [646] - ok
# [647] - No Difference A vs B
# [647] - ok
# [648] - No Difference A vs B
# [648] - ok
# [649] - No Difference A vs B
# [649] - ok
# [65] - Difference A vs B: [10, 1, 185, 5, 270]
# [65] - ok
# [650] - No Difference A vs B
# [650] - ok
# [651] - No Difference A vs B
# [651] - ok
# [652] - No Difference A vs B
# [652] - ok
# [653] - No Difference A vs B
# [653] - ok
# [654] - No Difference A vs B
# [654] - ok
# [655] - No Difference A vs B
# [655] - Total errors: 1 - [0, 0, -1, 0, 0]
# [656] - No Difference A vs B
# [656] - ok
# [657] - No Difference A vs B
# [657] - ok
# [658] - No Difference A vs B
# [658] - Total errors: 2 - [-2, 0]
# [659] - No Difference A vs B
# [659] - ok
# [66] - No Difference A vs B
# [66] - Total errors: 55 - [8, 5, 23, 17, 2]
# [660] - No Difference A vs B
# [660] - ok
# [661] - Difference A vs B: [0, 0, 1, 1, 0]
# [661] - ok
# [662] - Difference A vs B: [1, 2, 204, 18, 0]
# [662] - Total errors: 2 - [-2, 0, 0, 0]
# [663] - No Difference A vs B
# [663] - ok
# [664] - Difference A vs B: [0, 0, 15, 0, 1]
# [664] - ok
# [665] - No Difference A vs B
# [665] - ok
# [666] - No Difference A vs B
# [666] - ok
# [667] - No Difference A vs B
# [667] - ok
# [668] - Difference A vs B: [0, 0, 0, 1, 0]
# [668] - ok
# [669] - No Difference A vs B
# [669] - ok
# [67] - Difference A vs B: [0, 0, 1, 0, 0]
# [67] - Total errors: 6 - [-1, -4, 0, 0, -1]
# [670] - No Difference A vs B
# [670] - ok
# [671] - Difference A vs B: [0, 0, 0, 2, 0]
# [671] - Total errors: 1 - [0, 0, 0, -1]
# [672] - No Difference A vs B
# [672] - ok
# [673] - No Difference A vs B
# [673] - ok
# [674] - Difference A vs B: [0, 0, 39, 2, 91]
# [674] - ok
# [675] - No Difference A vs B
# [675] - Total errors: 2 - [0, 0, 0, -2]
# [676] - No Difference A vs B
# [676] - Total errors: 1 - [0, 0, 0, 0, -1]
# [677] - No Difference A vs B
# [677] - ok
# [678] - No Difference A vs B
# [678] - ok
# [679] - Difference A vs B: [0, 0, 1, 0, 0]
# [679] - Total errors: 2 - [0, -2, 0, 0, 0]
# [68] - No Difference A vs B
# [68] - ok
# [680] - Difference A vs B: [0, 0, 17, 1, 146]
# [680] - ok
# [681] - No Difference A vs B
# [681] - ok
# [682] - No Difference A vs B
# [682] - ok
# [683] - No Difference A vs B
# [683] - ok
# [684] - Difference A vs B: [0, 0, 10, 0, 0]
# [684] - ok
# [685] - No Difference A vs B
# [685] - ok
# [686] - No Difference A vs B
# [686] - Total errors: 2 - [0, -2, 0]
# [687] - Difference A vs B: [6, 4, 72, 9, 3]
# [687] - ok
# [688] - No Difference A vs B
# [688] - ok
# [689] - No Difference A vs B
# [689] - ok
# [69] - No Difference A vs B
# [69] - ok
# [690] - No Difference A vs B
# [690] - ok
# [691] - No Difference A vs B
# [691] - ok
# [692] - No Difference A vs B
# [692] - ok
# [693] - No Difference A vs B
# [693] - ok
# [694] - No Difference A vs B
# [694] - ok
# [695] - No Difference A vs B
# [695] - ok
# [696] - No Difference A vs B
# [696] - ok
# [697] - No Difference A vs B
# [697] - ok
# [698] - No Difference A vs B
# [698] - ok
# [699] - No Difference A vs B
# [699] - Total errors: 2 - [-2, 0, 0, 0, 0]
# [7] - No Difference A vs B
# [7] - ok
# [70] - Difference A vs B: [8, 8, 15, 614, 0]
# [70] - ok
# [700] - No Difference A vs B
# [700] - Total errors: 3 - [0, 0, -1, -2, 0]
# [701] - Difference A vs B: [0, 0, 52, 9, 132]
# [701] - ok
# [702] - No Difference A vs B
# [702] - ok
# [703] - Difference A vs B: [0, 0, 0, 1, 0]
# [703] - ok
# [704] - Difference A vs B: [2, 0, 120, 6, 59]
# [704] - ok
# [705] - No Difference A vs B
# [705] - ok
# [706] - No Difference A vs B
# [706] - Total errors: 1 - [0, -1, 0, 0]
# [707] - No Difference A vs B
# [707] - Total errors: 1 - [0, -1, 0, 0]
# [708] - No Difference A vs B
# [708] - ok
# [709] - No Difference A vs B
# [709] - ok
# [71] - Difference A vs B: [3, 2, 21, 18, 0]
# [71] - ok
# [710] - No Difference A vs B
# [710] - Total errors: 1 - [-1, 0]
# [711] - No Difference A vs B
# [711] - ok
# [712] - Difference A vs B: [3, 0, 0, 63, 0]
# [712] - Total errors: 1 - [0, -1]
# [713] - No Difference A vs B
# [713] - ok
# [714] - No Difference A vs B
# [714] - ok
# [715] - No Difference A vs B
# [715] - ok
# [716] - No Difference A vs B
# [716] - ok
# [717] - Difference A vs B: [0, 0, 1, 0, 0]
# [717] - ok
# [718] - Difference A vs B: [13, 3, 39, 1, 42]
# [718] - ok
# [719] - No Difference A vs B
# [719] - ok
# [72] - No Difference A vs B
# [72] - ok
# [720] - No Difference A vs B
# [720] - ok
# [721] - Difference A vs B: [5, 1, 38, 13, 0]
# [721] - ok
# [722] - Difference A vs B: [0, 0, 41, 1, 88]
# [722] - ok
# [723] - No Difference A vs B
# [723] - ok
# [724] - No Difference A vs B
# [724] - Total errors: 3 - [0, -1, 0, -2]
# [725] - No Difference A vs B
# [725] - ok
# [726] - No Difference A vs B
# [726] - ok
# [727] - Difference A vs B: [1, 0, 0, 0, 0]
# [727] - ok
# [728] - No Difference A vs B
# [728] - ok
# [729] - No Difference A vs B
# [729] - Total errors: 1 - [0, 0, 0, -1]
# [73] - No Difference A vs B
# [73] - Total errors: 1 - [0, 0, 0, -1]
# [730] - No Difference A vs B
# [730] - ok
# [731] - No Difference A vs B
# [731] - ok
# [732] - No Difference A vs B
# [732] - Total errors: 2 - [0, -2]
# [733] - No Difference A vs B
# [733] - ok
# [734] - No Difference A vs B
# [734] - ok
# [735] - No Difference A vs B
# [735] - ok
# [736] - No Difference A vs B
# [736] - ok
# [737] - No Difference A vs B
# [737] - ok
# [738] - No Difference A vs B
# [738] - ok
# [739] - No Difference A vs B
# [739] - Total errors: 3 - [0, -3, 0, 0]
# [74] - Difference A vs B: [0, 0, 0, 1, 0]
# [74] - ok
# [740] - No Difference A vs B
# [740] - ok
# [741] - Difference A vs B: [4, 0, 132, 7, 176]
# [741] - Total errors: 2 - [-2, 0, 0, 0, 0]
# [742] - No Difference A vs B
# [742] - Total errors: 1 - [1, 0, 0, 0, 0]
# [743] - Difference A vs B: [0, 0, 28, 0, 56]
# [743] - ok
# [744] - Difference A vs B: [6, 3, 51, 496, 0]
# [744] - Total errors: 2 - [0, 0, 0, -2]
# [745] - Difference A vs B: [2, 0, 210, 16, 180]
# [745] - Total errors: 1 - [0, 0, -1, 0, 0]
# [746] - No Difference A vs B
# [746] - ok
# [747] - Difference A vs B: [8, 0, 156, 12, 223]
# [747] - ok
# [748] - No Difference A vs B
# [748] - Total errors: 1 - [-1]
# [749] - No Difference A vs B
# [749] - ok
# [75] - No Difference A vs B
# [75] - ok
# [750] - No Difference A vs B
# [750] - Total errors: 4 - [-2, 0, 0, -2]
# [751] - No Difference A vs B
# [751] - Total errors: 3 - [-3]
# [752] - No Difference A vs B
# [752] - ok
# [753] - No Difference A vs B
# [753] - ok
# [754] - No Difference A vs B
# [754] - Total errors: 2 - [0, 0, -2]
# [755] - No Difference A vs B
# [755] - ok
# [536] - No Difference A vs B
# [536] - ok
# [537] - Difference A vs B: [1, 0, 0, 0, 0]
# [537] - ok
# [538] - Difference A vs B: [3, 0, 28, 2, 98]
# [538] - Total errors: 2 - [-1, -1, 0, 0, 0]
# [539] - No Difference A vs B
# [539] - Total errors: 1 - [-1, 0]
# [54] - No Difference A vs B
# [54] - ok
# [540] - No Difference A vs B
# [540] - ok
# [541] - No Difference A vs B
# [541] - ok
# [542] - No Difference A vs B
# [542] - ok
# [543] - No Difference A vs B
# [543] - Total errors: 1 - [-1, 0, 0]
# [544] - No Difference A vs B
# [544] - Total errors: 1 - [0, 1, 0, 0]
# [545] - No Difference A vs B
# [545] - ok
# [546] - No Difference A vs B
# [546] - ok
# [547] - Difference A vs B: [0, 0, 0, 2, 0]
# [547] - ok
# [548] - No Difference A vs B
# [548] - ok
# [549] - No Difference A vs B
# [549] - ok
# [55] - No Difference A vs B
# [55] - ok
# [550] - No Difference A vs B
# [550] - ok
# [551] - No Difference A vs B
# [551] - ok
# [552] - No Difference A vs B
# [552] - Total errors: 1 - [0, 0, 0, 1]
# [553] - No Difference A vs B
# [553] - Total errors: 1 - [-1, 0, 0, 0]
# [554] - No Difference A vs B
# [554] - Total errors: 2 - [-1, -1, 0, 0, 0]
# [555] - No Difference A vs B
# [555] - Total errors: 2 - [-2, 0, 0, 0]
# [556] - Difference A vs B: [0, 0, 82, 23, 88]
# [556] - ok
# [557] - No Difference A vs B
# [557] - ok
# [558] - No Difference A vs B
# [558] - ok
# [559] - No Difference A vs B
# [559] - ok
# [56] - Difference A vs B: [0, 0, 21, 0, 25]
# [56] - ok
# [560] - Difference A vs B: [0, 0, 0, 1, 0]
# [560] - ok
# [561] - No Difference A vs B
# [561] - ok
# [562] - Difference A vs B: [0, 0, 0, 2, 0]
# [562] - ok
# [563] - Difference A vs B: [0, 0, 0, 0, 2]
# [563] - ok
# [564] - No Difference A vs B
# [564] - ok
# [565] - No Difference A vs B
# [565] - ok
# [566] - No Difference A vs B
# [566] - ok
# [567] - No Difference A vs B
# [567] - ok
# [568] - No Difference A vs B
# [568] - Total errors: 2 - [0, 0, -2, 0]
# [569] - No Difference A vs B
# [569] - ok
# [57] - No Difference A vs B
# [57] - ok
# [570] - No Difference A vs B
# [570] - ok
# [571] - Difference A vs B: [0, 0, 3, 0, 0]
# [571] - ok
# [572] - No Difference A vs B
# [572] - ok
# [573] - No Difference A vs B
# [573] - ok
# [574] - No Difference A vs B
# [574] - Total errors: 3 - [0, -2, -1, 0, 0]
# [575] - Difference A vs B: [0, 0, 1, 0, 0]
# [575] - ok
# [576] - No Difference A vs B
# [576] - ok
# [577] - No Difference A vs B
# [577] - Total errors: 1 - [0, 0, -1, 0]
# [578] - Difference A vs B: [0, 0, 1, 0, 0]
# [578] - Total errors: 2 - [0, 0, -1, -1]
# [579] - No Difference A vs B
# [579] - ok
# [58] - Difference A vs B: [5, 0, 98, 49, 135]
# [58] - Total errors: 1 - [1, 0, 0, 0, 0]
# [580] - No Difference A vs B
# [580] - ok
# [581] - No Difference A vs B
# [581] - ok
# [582] - No Difference A vs B
# [582] - ok
# [583] - No Difference A vs B
# [583] - ok
# [584] - No Difference A vs B
# [584] - Total errors: 1 - [0, 0, -1]
# [585] - No Difference A vs B
# [585] - Total errors: 8 - [0, -3, -1, -4]
# [586] - No Difference A vs B
# [586] - ok
# [587] - Difference A vs B: [29, 13, 200, 75, 268]
# [587] - Total errors: 9 - [0, -1, 0, -2, -6]
# [588] - No Difference A vs B
# [588] - ok
# [589] - No Difference A vs B
# [589] - ok
# [59] - Difference A vs B: [0, 0, 0, 1, 0]
# [59] - ok
# [590] - Difference A vs B: [8, 6, 280, 25, 300]
# [590] - ok
# [591] - Difference A vs B: [22, 14, 134, 116, 43]
# [591] - ok
# [592] - No Difference A vs B
# [592] - ok
# [593] - No Difference A vs B
# [593] - Total errors: 53 - [0, 0, 0, 53]
# [594] - No Difference A vs B
# [594] - ok
# [595] - No Difference A vs B
# [595] - Total errors: 3 - [0, -2, -1]
# [596] - No Difference A vs B
# [596] - ok
# [597] - No Difference A vs B
# [597] - ok
# [598] - No Difference A vs B
# [598] - Total errors: 6 - [-2, -4, 0, 0]
# [599] - No Difference A vs B
# [599] - ok
# [6] - No Difference A vs B
# [6] - ok
# [60] - No Difference A vs B
# [60] - ok
# [600] - No Difference A vs B
# [600] - ok
# [601] - No Difference A vs B
# [601] - ok
# [602] - No Difference A vs B
# [602] - ok
# [603] - No Difference A vs B
# [603] - ok
# [604] - Difference A vs B: [0, 0, 61, 51, 1]
# [604] - Total errors: 2 - [0, -1, 0, -1, 0]
# [605] - No Difference A vs B
# [605] - ok
# [606] - Difference A vs B: [8, 3, 199, 8, 211]
# [606] - Total errors: 1 - [-1, 0, 0, 0, 0]
# [607] - No Difference A vs B
# [607] - Total errors: 2 - [0, -1, -1]
# [608] - No Difference A vs B
# [608] - ok
# [609] - No Difference A vs B
# [609] - ok
# [61] - No Difference A vs B
# [61] - ok
# [610] - Difference A vs B: [0, 0, 0, 1, 0]
# [610] - ok
# [611] - No Difference A vs B
# [611] - ok
# [612] - No Difference A vs B
# [612] - ok
# [613] - No Difference A vs B
# [613] - ok
# [614] - Difference A vs B: [1, 0, 5, 10, 0]
# [614] - ok
# [615] - No Difference A vs B
# [615] - ok
# [616] - No Difference A vs B
# [616] - ok
# [617] - No Difference A vs B
# [617] - ok
# [618] - No Difference A vs B
# [618] - ok
# [619] - No Difference A vs B
# [619] - Total errors: 1 - [0, 0, 0, -1, 0]
# [62] - Difference A vs B: [0, 0, 19, 0, 0]
# [62] - Total errors: 1 - [0, 0, -1, 0, 0]
# [620] - No Difference A vs B
# [620] - ok
# [621] - Difference A vs B: [10, 10, 53, 36, 30]
# [621] - Total errors: 7 - [-5, -2, 0, 0, 0]
# [622] - Difference A vs B: [0, 0, 0, 0, 2]
# [622] - ok
# [623] - No Difference A vs B
# [623] - ok
# [624] - No Difference A vs B
# [624] - ok
# [625] - Difference A vs B: [17, 4, 123, 9, 129]
# [625] - ok
# [626] - No Difference A vs B
# [626] - ok
# [627] - No Difference A vs B
# [627] - ok
# [628] - No Difference A vs B
# [628] - ok
# [629] - Difference A vs B: [0, 0, 1, 0, 1]
# [629] - Total errors: 6 - [-3, -3, 0, 0, 0]
# [63] - No Difference A vs B
# [63] - Total errors: 1 - [0, 0, 0, 0, -1]
# [630] - No Difference A vs B
# [630] - ok
# [631] - No Difference A vs B
# [631] - ok
# [632] - No Difference A vs B
# [632] - Total errors: 1 - [-1, 0, 0, 0]
# [633] - No Difference A vs B
# [633] - Total errors: 2 - [0, 0, 0, 0, -2]
# [634] - No Difference A vs B
# [634] - ok
# [635] - No Difference A vs B
# [635] - ok
# [636] - No Difference A vs B
# [636] - ok
# [637] - No Difference A vs B
# [637] - ok
# [638] - No Difference A vs B
# [638] - ok
# [639] - Difference A vs B: [0, 0, 0, 1, 0]
# [639] - ok
# [64] - No Difference A vs B
# [64] - ok
# [640] - No Difference A vs B
# [640] - ok
# [641] - No Difference A vs B
# [641] - ok
# [642] - No Difference A vs B
# [642] - ok
# [643] - No Difference A vs B
# [643] - Total errors: 9 - [0, -1, -8]
# [644] - No Difference A vs B
# [644] - ok
# [645] - No Difference A vs B
# [645] - Total errors: 2 - [0, 0, 0, -1, -1]
# [426] - No Difference A vs B
# [426] - Total errors: 16 - [0, 1, 5, 10, 0]
# [427] - No Difference A vs B
# [427] - ok
# [428] - No Difference A vs B
# [428] - ok
# [429] - Difference A vs B: [0, 0, 13, 0, 0]
# [429] - ok
# [43] - Difference A vs B: [14, 2, 294, 30, 188]
# [43] - ok
# [430] - No Difference A vs B
# [430] - ok
# [431] - No Difference A vs B
# [431] - Total errors: 2 - [-1, 0, -1]
# [432] - No Difference A vs B
# [432] - ok
# [433] - No Difference A vs B
# [433] - Total errors: 2 - [0, 0, 2]
# [434] - Difference A vs B: [0, 0, 0, 6, 0]
# [434] - ok
# [435] - No Difference A vs B
# [435] - ok
# [436] - No Difference A vs B
# [436] - ok
# [437] - Difference A vs B: [8, 0, 98, 1, 184]
# [437] - Total errors: 6 - [-6, 0, 0, 0, 0]
# [438] - Difference A vs B: [0, 0, 32, 0, 84]
# [438] - ok
# [439] - No Difference A vs B
# [439] - ok
# [44] - No Difference A vs B
# [44] - ok
# [440] - No Difference A vs B
# [440] - ok
# [441] - No Difference A vs B
# [441] - Total errors: 1 - [0, 0, -1]
# [442] - No Difference A vs B
# [442] - ok
# [443] - No Difference A vs B
# [443] - ok
# [444] - No Difference A vs B
# [444] - ok
# [445] - No Difference A vs B
# [445] - ok
# [446] - No Difference A vs B
# [446] - ok
# [447] - No Difference A vs B
# [447] - ok
# [448] - Difference A vs B: [1, 0, 0, 0, 0]
# [448] - ok
# [449] - No Difference A vs B
# [449] - ok
# [45] - No Difference A vs B
# [45] - ok
# [450] - No Difference A vs B
# [450] - ok
# [451] - No Difference A vs B
# [451] - ok
# [452] - Difference A vs B: [7, 0, 114, 5, 93]
# [452] - Total errors: 1 - [1, 0, 0, 0, 0]
# [453] - No Difference A vs B
# [453] - ok
# [454] - No Difference A vs B
# [454] - ok
# [455] - No Difference A vs B
# [455] - ok
# [456] - No Difference A vs B
# [456] - ok
# [457] - No Difference A vs B
# [457] - ok
# [458] - No Difference A vs B
# [458] - ok
# [459] - No Difference A vs B
# [459] - ok
# [46] - No Difference A vs B
# [46] - ok
# [460] - No Difference A vs B
# [460] - Total errors: 1 - [0, 0, 0, -1]
# [461] - Difference A vs B: [0, 0, 0, 2, 0]
# [461] - ok
# [462] - No Difference A vs B
# [462] - Total errors: 2 - [-1, 0, 0, 0, -1]
# [463] - No Difference A vs B
# [463] - ok
# [464] - No Difference A vs B
# [464] - ok
# [465] - Difference A vs B: [0, 0, 4, 0, 0]
# [465] - Total errors: 1 - [0, 0, 0, -1]
# [466] - No Difference A vs B
# [466] - ok
# [467] - No Difference A vs B
# [467] - ok
# [468] - No Difference A vs B
# [468] - ok
# [469] - No Difference A vs B
# [469] - ok
# [47] - No Difference A vs B
# [47] - Total errors: 2 - [0, -2, 0, 0, 0]
# [470] - No Difference A vs B
# [470] - ok
# [471] - No Difference A vs B
# [471] - ok
# [472] - No Difference A vs B
# [472] - ok
# [473] - No Difference A vs B
# [473] - Total errors: 3 - [0, 0, 3]
# [474] - No Difference A vs B
# [474] - ok
# [475] - Difference A vs B: [0, 0, 17, 0, 0]
# [475] - ok
# [476] - Difference A vs B: [0, 0, 0, 1, 0]
# [476] - Total errors: 4 - [0, -4, 0]
# [477] - No Difference A vs B
# [477] - ok
# [478] - Difference A vs B: [0, 0, 0, 1, 0]
# [478] - ok
# [479] - No Difference A vs B
# [479] - Total errors: 1 - [0, -1]
# [48] - Difference A vs B: [0, 0, 1, 1, 0]
# [48] - ok
# [480] - No Difference A vs B
# [480] - ok
# [481] - No Difference A vs B
# [481] - ok
# [482] - No Difference A vs B
# [482] - Total errors: 1 - [0, 0, 0, -1, 0]
# [483] - No Difference A vs B
# [483] - Total errors: 2 - [0, -1, 0, -1]
# [484] - No Difference A vs B
# [484] - ok
# [485] - No Difference A vs B
# [485] - ok
# [486] - No Difference A vs B
# [486] - ok
# [487] - No Difference A vs B
# [487] - ok
# [488] - Difference A vs B: [0, 0, 69, 19, 0]
# [488] - ok
# [489] - Difference A vs B: [0, 0, 0, 2, 0]
# [489] - ok
# [49] - No Difference A vs B
# [49] - ok
# [490] - No Difference A vs B
# [490] - ok
# [491] - Difference A vs B: [0, 1, 0, 3, 0]
# [491] - ok
# [492] - Difference A vs B: [0, 0, 0, 1, 0]
# [492] - Total errors: 1 - [0, -1, 0, 0, 0]
# [493] - No Difference A vs B
# [493] - ok
# [494] - Difference A vs B: [0, 0, 1, 0, 0]
# [494] - ok
# [495] - No Difference A vs B
# [495] - Total errors: 3 - [-3, 0, 0, 0]
# [496] - No Difference A vs B
# [496] - ok
# [497] - No Difference A vs B
# [497] - ok
# [498] - Difference A vs B: [0, 0, 0, 1, 0]
# [498] - ok
# [499] - No Difference A vs B
# [499] - ok
# [5] - No Difference A vs B
# [5] - ok
# [50] - No Difference A vs B
# [50] - ok
# [500] - No Difference A vs B
# [500] - Total errors: 4 - [-2, 1, -1]
# [501] - No Difference A vs B
# [501] - ok
# [502] - Difference A vs B: [0, 0, 1, 1, 0]
# [502] - ok
# [503] - No Difference A vs B
# [503] - ok
# [504] - No Difference A vs B
# [504] - ok
# [505] - No Difference A vs B
# [505] - Total errors: 2 - [0, -1, -1]
# [506] - No Difference A vs B
# [506] - ok
# [507] - No Difference A vs B
# [507] - ok
# [508] - No Difference A vs B
# [508] - ok
# [509] - Difference A vs B: [0, 0, 1, 0, 1]
# [509] - Total errors: 3 - [0, -1, -1, 0, -1]
# [51] - No Difference A vs B
# [51] - ok
# [510] - No Difference A vs B
# [510] - Total errors: 3 - [3, 0]
# [511] - No Difference A vs B
# [511] - ok
# [512] - No Difference A vs B
# [512] - ok
# [513] - No Difference A vs B
# [513] - ok
# [514] - Difference A vs B: [2, 0, 204, 41, 0]
# [514] - ok
# [515] - No Difference A vs B
# [515] - ok
# [516] - Difference A vs B: [0, 0, 0, 1, 0]
# [516] - Total errors: 8 - [-4, -3, -1, 0, 0]
# [517] - No Difference A vs B
# [517] - ok
# [518] - No Difference A vs B
# [518] - Total errors: 1 - [0, 0, 0, -1]
# [519] - No Difference A vs B
# [519] - ok
# [52] - No Difference A vs B
# [52] - Total errors: 1 - [-1, 0, 0, 0]
# [520] - No Difference A vs B
# [520] - ok
# [521] - No Difference A vs B
# [521] - ok
# [522] - Difference A vs B: [0, 0, 0, 2, 0]
# [522] - ok
# [523] - Difference A vs B: [1, 0, 0, 0, 0]
# [523] - ok
# [524] - No Difference A vs B
# [524] - Total errors: 3 - [-1, -2, 0, 0]
# [525] - No Difference A vs B
# [525] - ok
# [526] - Difference A vs B: [5, 10, 20, 19, 13]
# [526] - Total errors: 1 - [1, 0, 0, 0, 0]
# [527] - No Difference A vs B
# [527] - ok
# [528] - No Difference A vs B
# [528] - ok
# [529] - No Difference A vs B
# [529] - Total errors: 21 - [0, -1, -1, -19]
# [53] - No Difference A vs B
# [53] - ok
# [530] - No Difference A vs B
# [530] - ok
# [531] - Difference A vs B: [0, 9, 5, 6, 0]
# [531] - ok
# [532] - No Difference A vs B
# [532] - ok
# [533] - No Difference A vs B
# [533] - ok
# [534] - No Difference A vs B
# [534] - ok
# [535] - No Difference A vs B
# [535] - ok
# [316] - No Difference A vs B
# [316] - ok
# [317] - No Difference A vs B
# [317] - ok
# [318] - No Difference A vs B
# [318] - ok
# [319] - Difference A vs B: [17, 12, 145, 68, 49]
# [319] - ok
# [32] - Difference A vs B: [0, 0, 153, 6, 49]
# [32] - ok
# [320] - Difference A vs B: [4, 0, 101, 14, 10]
# [320] - ok
# [321] - No Difference A vs B
# [321] - ok
# [322] - No Difference A vs B
# [322] - ok
# [323] - No Difference A vs B
# [323] - Total errors: 2 - [-2, 0, 0]
# [324] - Difference A vs B: [0, 0, 1, 0, 0]
# [324] - ok
# [325] - No Difference A vs B
# [325] - Total errors: 1 - [0, 0, -1]
# [326] - Difference A vs B: [0, 0, 0, 2, 0]
# [326] - ok
# [327] - No Difference A vs B
# [327] - ok
# [328] - No Difference A vs B
# [328] - Total errors: 2 - [-1, 0, 0, -1, 0]
# [329] - No Difference A vs B
# [329] - ok
# [33] - No Difference A vs B
# [33] - ok
# [330] - No Difference A vs B
# [330] - Total errors: 2 - [0, 0, -2]
# [331] - No Difference A vs B
# [331] - ok
# [332] - No Difference A vs B
# [332] - ok
# [333] - Difference A vs B: [0, 0, 0, 2, 0]
# [333] - ok
# [334] - No Difference A vs B
# [334] - ok
# [335] - No Difference A vs B
# [335] - Total errors: 1 - [0, 0, -1, 0]
# [336] - No Difference A vs B
# [336] - ok
# [337] - No Difference A vs B
# [337] - ok
# [338] - Difference A vs B: [19, 4, 255, 33, 248]
# [338] - Total errors: 1 - [0, 0, 0, 0, -1]
# [339] - Difference A vs B: [0, 0, 1, 0, 0]
# [339] - ok
# [34] - Difference A vs B: [4, 1, 14, 0, 0]
# [34] - Total errors: 113 - [0, 0, -113]
# [340] - Difference A vs B: [3, 0, 45, 3, 120]
# [340] - ok
# [341] - No Difference A vs B
# [341] - ok
# [342] - Difference A vs B: [0, 0, 4, 0, 0]
# [342] - Total errors: 3 - [0, -3, 0]
# [343] - No Difference A vs B
# [343] - ok
# [344] - Difference A vs B: [2, 0, 16, 0, 0]
# [344] - Total errors: 2 - [0, -2]
# [345] - No Difference A vs B
# [345] - ok
# [346] - No Difference A vs B
# [346] - ok
# [347] - No Difference A vs B
# [347] - ok
# [348] - No Difference A vs B
# [348] - ok
# [349] - No Difference A vs B
# [349] - ok
# [35] - No Difference A vs B
# [35] - ok
# [350] - No Difference A vs B
# [350] - ok
# [351] - No Difference A vs B
# [351] - Total errors: 1 - [-1]
# [352] - No Difference A vs B
# [352] - ok
# [353] - Difference A vs B: [0, 0, 2, 0, 0]
# [353] - ok
# [354] - No Difference A vs B
# [354] - ok
# [355] - No Difference A vs B
# [355] - ok
# [356] - No Difference A vs B
# [356] - ok
# [357] - No Difference A vs B
# [357] - ok
# [358] - No Difference A vs B
# [358] - ok
# [359] - No Difference A vs B
# [359] - Total errors: 4 - [0, -1, -3, 0, 0]
# [36] - No Difference A vs B
# [36] - Total errors: 3 - [-1, -2]
# [360] - Difference A vs B: [0, 0, 0, 2, 0]
# [360] - ok
# [361] - Difference A vs B: [0, 0, 27, 1, 37]
# [361] - Total errors: 1 - [-1, 0, 0, 0, 0]
# [362] - Difference A vs B: [0, 0, 27, 0, 34]
# [362] - Total errors: 3 - [0, 0, 0, -1, -2]
# [363] - No Difference A vs B
# [363] - ok
# [364] - No Difference A vs B
# [364] - ok
# [365] - No Difference A vs B
# [365] - Total errors: 2 - [-1, -1]
# [366] - No Difference A vs B
# [366] - ok
# [367] - No Difference A vs B
# [367] - ok
# [368] - No Difference A vs B
# [368] - Total errors: 2 - [-1, -1, 0, 0]
# [369] - No Difference A vs B
# [369] - Total errors: 2 - [0, -2, 0]
# [37] - No Difference A vs B
# [37] - ok
# [370] - No Difference A vs B
# [370] - ok
# [371] - No Difference A vs B
# [371] - ok
# [372] - Difference A vs B: [29, 6, 136, 33, 82]
# [372] - ok
# [373] - No Difference A vs B
# [373] - ok
# [374] - No Difference A vs B
# [374] - ok
# [375] - No Difference A vs B
# [375] - Total errors: 1 - [-1]
# [376] - No Difference A vs B
# [376] - ok
# [377] - Difference A vs B: [3, 0, 19, 2, 29]
# [377] - ok
# [378] - No Difference A vs B
# [378] - ok
# [379] - No Difference A vs B
# [379] - ok
# [38] - No Difference A vs B
# [38] - Total errors: 3 - [0, -3]
# [380] - Difference A vs B: [0, 0, 144, 0, 0]
# [380] - ok
# [381] - No Difference A vs B
# [381] - ok
# [382] - Difference A vs B: [0, 0, 0, 1, 0]
# [382] - ok
# [383] - Difference A vs B: [0, 0, 0, 2, 0]
# [383] - Total errors: 3 - [0, -2, 0, -1]
# [384] - No Difference A vs B
# [384] - ok
# [385] - No Difference A vs B
# [385] - ok
# [386] - No Difference A vs B
# [386] - Total errors: 2 - [0, -2, 0, 0, 0]
# [387] - No Difference A vs B
# [387] - ok
# [388] - Difference A vs B: [0, 0, 0, 2, 0]
# [388] - Total errors: 1 - [-1, 0, 0]
# [389] - No Difference A vs B
# [389] - ok
# [39] - No Difference A vs B
# [39] - ok
# [390] - No Difference A vs B
# [390] - ok
# [391] - No Difference A vs B
# [391] - ok
# [392] - No Difference A vs B
# [392] - ok
# [393] - No Difference A vs B
# [393] - ok
# [394] - No Difference A vs B
# [394] - Total errors: 4 - [0, -4]
# [395] - No Difference A vs B
# [395] - Total errors: 3 - [0, -2, -1]
# [396] - No Difference A vs B
# [396] - ok
# [397] - No Difference A vs B
# [397] - ok
# [398] - Difference A vs B: [1, 0, 0, 1, 0]
# [398] - Total errors: 3 - [-3, 0]
# [399] - No Difference A vs B
# [399] - ok
# [4] - No Difference A vs B
# [4] - ok
# [40] - No Difference A vs B
# [40] - Total errors: 2 - [0, 0, -1, -1]
# [400] - No Difference A vs B
# [400] - ok
# [401] - Difference A vs B: [0, 0, 0, 2, 0]
# [401] - ok
# [402] - Difference A vs B: [1, 3, 245, 40, 0]
# [402] - ok
# [403] - Difference A vs B: [0, 0, 18, 50, 0]
# [403] - ok
# [404] - No Difference A vs B
# [404] - ok
# [405] - No Difference A vs B
# [405] - Total errors: 3 - [0, 0, 0, -3]
# [406] - Difference A vs B: [10, 12, 20, 46, 3]
# [406] - Total errors: 122 - [0, 0, -121, -1, 0]
# [407] - No Difference A vs B
# [407] - ok
# [408] - No Difference A vs B
# [408] - ok
# [409] - No Difference A vs B
# [409] - Total errors: 3 - [0, -2, -1, 0]
# [41] - Difference A vs B: [0, 0, 1, 0, 0]
# [41] - ok
# [410] - No Difference A vs B
# [410] - Total errors: 1 - [0, -1]
# [411] - Difference A vs B: [6, 0, 317, 299, 0]
# [411] - ok
# [412] - No Difference A vs B
# [412] - Total errors: 7 - [0, -6, -1, 0]
# [413] - No Difference A vs B
# [413] - ok
# [414] - No Difference A vs B
# [414] - ok
# [415] - No Difference A vs B
# [415] - ok
# [416] - Difference A vs B: [1, 20, 7, 337, 0]
# [416] - Total errors: 2 - [0, 0, 0, -2]
# [417] - No Difference A vs B
# [417] - ok
# [418] - Difference A vs B: [0, 0, 123, 2, 0]
# [418] - Total errors: 1 - [-1, 0, 0, 0]
# [419] - No Difference A vs B
# [419] - ok
# [42] - No Difference A vs B
# [42] - ok
# [420] - Difference A vs B: [0, 0, 10, 1, 14]
# [420] - ok
# [421] - No Difference A vs B
# [421] - ok
# [422] - Difference A vs B: [1, 0, 0, 0, 0]
# [422] - ok
# [423] - No Difference A vs B
# [423] - ok
# [424] - No Difference A vs B
# [424] - ok
# [425] - No Difference A vs B
# [425] - ok
# [206] - No Difference A vs B
# [206] - ok
# [207] - No Difference A vs B
# [207] - Total errors: 3 - [1, -2]
# [208] - No Difference A vs B
# [208] - ok
# [209] - No Difference A vs B
# [209] - ok
# [21] - Difference A vs B: [1, 0, 0, 0, 0]
# [21] - Total errors: 5 - [-5]
# [210] - No Difference A vs B
# [210] - ok
# [211] - Difference A vs B: [3, 0, 79, 5, 242]
# [211] - Total errors: 1 - [0, -1, 0, 0, 0]
# [212] - No Difference A vs B
# [212] - ok
# [213] - Difference A vs B: [0, 0, 0, 1, 0]
# [213] - ok
# [214] - No Difference A vs B
# [214] - Total errors: 2 - [-2, 0, 0, 0]
# [215] - No Difference A vs B
# [215] - ok
# [216] - No Difference A vs B
# [216] - Total errors: 2 - [-1, -1, 0]
# [217] - Difference A vs B: [0, 0, 44, 1, 110]
# [217] - ok
# [218] - No Difference A vs B
# [218] - ok
# [219] - Difference A vs B: [0, 0, 0, 2, 0]
# [219] - ok
# [22] - No Difference A vs B
# [22] - ok
# [220] - No Difference A vs B
# [220] - ok
# [221] - No Difference A vs B
# [221] - Total errors: 1 - [1, 0, 0, 0, 0]
# [222] - No Difference A vs B
# [222] - ok
# [223] - No Difference A vs B
# [223] - ok
# [224] - Difference A vs B: [1, 0, 44, 1, 65]
# [224] - ok
# [225] - No Difference A vs B
# [225] - ok
# [226] - Difference A vs B: [4, 2, 92, 3, 144]
# [226] - ok
# [227] - No Difference A vs B
# [227] - ok
# [228] - No Difference A vs B
# [228] - ok
# [229] - No Difference A vs B
# [229] - ok
# [23] - No Difference A vs B
# [23] - ok
# [230] - No Difference A vs B
# [230] - ok
# [231] - No Difference A vs B
# [231] - ok
# [232] - No Difference A vs B
# [232] - ok
# [233] - No Difference A vs B
# [233] - ok
# [234] - No Difference A vs B
# [234] - ok
# [235] - Difference A vs B: [0, 0, 271, 96, 90]
# [235] - Total errors: 1 - [0, -1, 0, 0]
# [236] - No Difference A vs B
# [236] - ok
# [237] - No Difference A vs B
# [237] - ok
# [238] - No Difference A vs B
# [238] - ok
# [239] - No Difference A vs B
# [239] - ok
# [24] - No Difference A vs B
# [24] - ok
# [240] - Difference A vs B: [0, 0, 74, 2, 82]
# [240] - Total errors: 4 - [0, -3, 0, 0, -1]
# [241] - No Difference A vs B
# [241] - ok
# [242] - No Difference A vs B
# [242] - ok
# [243] - No Difference A vs B
# [243] - ok
# [244] - No Difference A vs B
# [244] - ok
# [245] - No Difference A vs B
# [245] - ok
# [246] - No Difference A vs B
# [246] - ok
# [247] - No Difference A vs B
# [247] - ok
# [248] - No Difference A vs B
# [248] - ok
# [249] - No Difference A vs B
# [249] - ok
# [25] - No Difference A vs B
# [25] - ok
# [250] - No Difference A vs B
# [250] - ok
# [251] - No Difference A vs B
# [251] - ok
# [252] - Difference A vs B: [0, 0, 4, 0, 0]
# [252] - Total errors: 4 - [-2, -2, 0, 0, 0]
# [253] - No Difference A vs B
# [253] - ok
# [254] - No Difference A vs B
# [254] - ok
# [255] - No Difference A vs B
# [255] - ok
# [256] - Difference A vs B: [0, 0, 72, 27, 59]
# [256] - Total errors: 1 - [0, 0, -1, 0]
# [257] - Difference A vs B: [1, 11, 23, 53, 9]
# [257] - ok
# [258] - Difference A vs B: [2, 3, 297, 209, 1]
# [258] - Total errors: 1 - [0, 0, 0, -1, 0]
# [259] - No Difference A vs B
# [259] - Total errors: 1 - [1, 0, 0, 0]
# [26] - No Difference A vs B
# [26] - ok
# [260] - No Difference A vs B
# [260] - ok
# [261] - No Difference A vs B
# [261] - ok
# [262] - No Difference A vs B
# [262] - ok
# [263] - No Difference A vs B
# [263] - ok
# [264] - No Difference A vs B
# [264] - ok
# [265] - No Difference A vs B
# [265] - Total errors: 3 - [0, -3]
# [266] - No Difference A vs B
# [266] - ok
# [267] - Difference A vs B: [0, 0, 0, 2, 0]
# [267] - ok
# [268] - No Difference A vs B
# [268] - ok
# [269] - No Difference A vs B
# [269] - ok
# [27] - No Difference A vs B
# [27] - ok
# [270] - Difference A vs B: [0, 0, 0, 1, 0]
# [270] - Total errors: 1 - [0, 0, -1]
# [271] - Difference A vs B: [3, 0, 260, 31, 209]
# [271] - Total errors: 1 - [0, 0, -1, 0, 0]
# [272] - No Difference A vs B
# [272] - ok
# [273] - Difference A vs B: [11, 3, 226, 7, 250]
# [273] - ok
# [274] - No Difference A vs B
# [274] - ok
# [275] - No Difference A vs B
# [275] - Total errors: 1 - [1, 0, 0, 0]
# [276] - No Difference A vs B
# [276] - ok
# [277] - No Difference A vs B
# [277] - Total errors: 1 - [0, 0, 0, -1]
# [278] - No Difference A vs B
# [278] - ok
# [279] - No Difference A vs B
# [279] - ok
# [28] - No Difference A vs B
# [28] - ok
# [280] - No Difference A vs B
# [280] - ok
# [281] - No Difference A vs B
# [281] - ok
# [282] - No Difference A vs B
# [282] - ok
# [283] - No Difference A vs B
# [283] - ok
# [284] - No Difference A vs B
# [284] - ok
# [285] - No Difference A vs B
# [285] - ok
# [286] - No Difference A vs B
# [286] - ok
# [287] - No Difference A vs B
# [287] - ok
# [288] - No Difference A vs B
# [288] - ok
# [289] - No Difference A vs B
# [289] - ok
# [29] - No Difference A vs B
# [29] - ok
# [290] - Difference A vs B: [1, 0, 0, 0, 0]
# [290] - Total errors: 1 - [-1]
# [291] - Difference A vs B: [17, 1, 206, 13, 227]
# [291] - Total errors: 2 - [2, 0, 0, 0, 0]
# [292] - Difference A vs B: [0, 0, 0, 1, 0]
# [292] - Total errors: 59 - [3, 2, 27, 27, 0]
# [293] - No Difference A vs B
# [293] - Total errors: 2 - [0, 0, 0, 0, -2]
# [294] - Difference A vs B: [0, 0, 0, 2, 0]
# [294] - ok
# [295] - No Difference A vs B
# [295] - ok
# [296] - No Difference A vs B
# [296] - ok
# [297] - No Difference A vs B
# [297] - Total errors: 4 - [0, -4, 0, 0]
# [298] - Difference A vs B: [0, 0, 58, 6, 175]
# [298] - Total errors: 1 - [0, 0, 0, 0, -1]
# [299] - Difference A vs B: [2, 0, 124, 13, 44]
# [299] - Total errors: 1 - [0, -1, 0, 0, 0]
# [3] - Difference A vs B: [4, 0, 5, 2, 3]
# [3] - Total errors: 80 - [-4, -36, -5, -35]
# [30] - Difference A vs B: [0, 0, 257, 0, 0]
# [30] - ok
# [300] - No Difference A vs B
# [300] - ok
# [301] - No Difference A vs B
# [301] - ok
# [302] - No Difference A vs B
# [302] - ok
# [303] - No Difference A vs B
# [303] - Total errors: 1 - [0, 0, 1]
# [304] - No Difference A vs B
# [304] - ok
# [305] - No Difference A vs B
# [305] - ok
# [306] - Difference A vs B: [0, 0, 7, 0, 0]
# [306] - ok
# [307] - No Difference A vs B
# [307] - ok
# [308] - No Difference A vs B
# [308] - ok
# [309] - No Difference A vs B
# [309] - Total errors: 1 - [0, 0, 0, -1]
# [31] - No Difference A vs B
# [31] - ok
# [310] - No Difference A vs B
# [310] - Total errors: 1 - [0, 0, 0, -1]
# [311] - Difference A vs B: [1, 0, 7, 9, 3]
# [311] - ok
# [312] - No Difference A vs B
# [312] - Total errors: 1 - [0, 0, -1, 0]
# [313] - No Difference A vs B
# [313] - ok
# [314] - No Difference A vs B
# [314] - ok
# [315] - No Difference A vs B
# [315] - ok
# [0] - Difference A vs B: [62, 12, 486, 42, 344]
# [0] - ok
# [1] - No Difference A vs B
# [1] - ok
# [10] - No Difference A vs B
# [10] - ok
# [100] - No Difference A vs B
# [100] - ok
# [101] - No Difference A vs B
# [101] - ok
# [102] - No Difference A vs B
# [102] - ok
# [103] - No Difference A vs B
# [103] - ok
# [104] - No Difference A vs B
# [104] - ok
# [105] - No Difference A vs B
# [105] - Total errors: 5 - [0, -1, -4, 0]
# [106] - No Difference A vs B
# [106] - ok
# [107] - No Difference A vs B
# [107] - ok
# [108] - No Difference A vs B
# [108] - Total errors: 1 - [-1, 0, 0]
# [109] - No Difference A vs B
# [109] - ok
# [11] - No Difference A vs B
# [11] - Total errors: 2 - [0, -2, 0, 0]
# [110] - No Difference A vs B
# [110] - Total errors: 2 - [0, 0, 0, 0, -2]
# [111] - Difference A vs B: [0, 0, 0, 0, 2]
# [111] - ok
# [112] - Difference A vs B: [2, 0, 336, 127, 0]
# [112] - ok
# [113] - No Difference A vs B
# [113] - ok
# [114] - No Difference A vs B
# [114] - ok
# [115] - No Difference A vs B
# [115] - ok
# [116] - No Difference A vs B
# [116] - ok
# [117] - No Difference A vs B
# [117] - ok
# [118] - No Difference A vs B
# [118] - ok
# [119] - Difference A vs B: [1, 3, 9, 2, 11]
# [119] - ok
# [12] - No Difference A vs B
# [12] - ok
# [120] - No Difference A vs B
# [120] - ok
# [121] - No Difference A vs B
# [121] - ok
# [122] - Difference A vs B: [7, 28, 36, 13, 0]
# [122] - Total errors: 5 - [0, 0, -3, -2]
# [123] - No Difference A vs B
# [123] - ok
# [124] - Difference A vs B: [0, 0, 2, 0, 0]
# [124] - ok
# [125] - No Difference A vs B
# [125] - ok
# [126] - Difference A vs B: [1, 0, 51, 1, 89]
# [126] - ok
# [127] - Difference A vs B: [0, 0, 1, 0, 0]
# [127] - Total errors: 2 - [0, -1, 0, -1]
# [128] - No Difference A vs B
# [128] - ok
# [129] - No Difference A vs B
# [129] - Total errors: 7 - [0, -7]
# [13] - No Difference A vs B
# [13] - Total errors: 1 - [-1, 0, 0, 0]
# [130] - No Difference A vs B
# [130] - ok
# [131] - Difference A vs B: [0, 0, 1, 0, 0]
# [131] - ok
# [132] - No Difference A vs B
# [132] - ok
# [133] - No Difference A vs B
# [133] - ok
# [134] - No Difference A vs B
# [134] - Total errors: 2 - [0, 0, -1, -1]
# [135] - No Difference A vs B
# [135] - ok
# [136] - No Difference A vs B
# [136] - Total errors: 1 - [0, 0, 0, -1]
# [137] - No Difference A vs B
# [137] - ok
# [138] - No Difference A vs B
# [138] - ok
# [139] - No Difference A vs B
# [139] - ok
# [14] - No Difference A vs B
# [14] - ok
# [140] - No Difference A vs B
# [140] - ok
# [141] - No Difference A vs B
# [141] - ok
# [142] - No Difference A vs B
# [142] - ok
# [143] - No Difference A vs B
# [143] - ok
# [144] - No Difference A vs B
# [144] - ok
# [145] - No Difference A vs B
# [145] - ok
# [146] - No Difference A vs B
# [146] - Total errors: 1 - [0, 0, -1, 0, 0]
# [147] - No Difference A vs B
# [147] - ok
# [148] - No Difference A vs B
# [148] - Total errors: 2 - [-1, -1]
# [149] - No Difference A vs B
# [149] - ok
# [15] - No Difference A vs B
# [15] - Total errors: 7 - [0, 0, -2, -5]
# [150] - No Difference A vs B
# [150] - ok
# [151] - No Difference A vs B
# [151] - ok
# [152] - No Difference A vs B
# [152] - ok
# [153] - No Difference A vs B
# [153] - ok
# [154] - No Difference A vs B
# [154] - ok
# [155] - No Difference A vs B
# [155] - Total errors: 1 - [0, 0, 0, 0, -1]
# [156] - No Difference A vs B
# [156] - ok
# [157] - No Difference A vs B
# [157] - ok
# [158] - Difference A vs B: [0, 0, 1, 0, 0]
# [158] - ok
# [159] - No Difference A vs B
# [159] - ok
# [16] - Difference A vs B: [0, 0, 0, 2, 0]
# [16] - ok
# [160] - Difference A vs B: [0, 0, 78, 5, 24]
# [160] - ok
# [161] - No Difference A vs B
# [161] - ok
# [162] - Difference A vs B: [0, 0, 0, 2, 0]
# [162] - ok
# [163] - Difference A vs B: [0, 0, 1, 0, 1]
# [163] - ok
# [164] - Difference A vs B: [7, 1, 168, 7, 160]
# [164] - ok
# [165] - No Difference A vs B
# [165] - ok
# [166] - Difference A vs B: [0, 0, 1, 0, 0]
# [166] - ok
# [167] - No Difference A vs B
# [167] - ok
# [168] - No Difference A vs B
# [168] - ok
# [169] - No Difference A vs B
# [169] - ok
# [17] - No Difference A vs B
# [17] - ok
# [170] - No Difference A vs B
# [170] - Total errors: 2 - [0, -1, 0, -1]
# [171] - No Difference A vs B
# [171] - ok
# [172] - No Difference A vs B
# [172] - ok
# [173] - No Difference A vs B
# [173] - ok
# [174] - Difference A vs B: [1, 0, 0, 0, 0]
# [174] - Total errors: 1 - [0, -1, 0]
# [175] - No Difference A vs B
# [175] - Total errors: 1 - [0, 0, -1]
# [176] - No Difference A vs B
# [176] - ok
# [177] - No Difference A vs B
# [177] - Total errors: 1 - [0, -1, 0]
# [178] - No Difference A vs B
# [178] - Total errors: 1 - [0, -1]
# [179] - No Difference A vs B
# [179] - ok
# [18] - No Difference A vs B
# [18] - Total errors: 1 - [0, -1]
# [180] - No Difference A vs B
# [180] - ok
# [181] - Difference A vs B: [3, 0, 0, 0, 0]
# [181] - Total errors: 2 - [0, 0, -1, -1, 0]
# [182] - No Difference A vs B
# [182] - ok
# [183] - No Difference A vs B
# [183] - ok
# [184] - Difference A vs B: [6, 16, 0, 7, 0]
# [184] - ok
# [185] - No Difference A vs B
# [185] - ok
# [186] - Difference A vs B: [0, 0, 98, 7, 0]
# [186] - Total errors: 1 - [0, -1, 0, 0]
# [187] - Difference A vs B: [41, 12, 548, 8, 434]
# [187] - Total errors: 3 - [-2, 0, -1, 0, 0]
# [188] - No Difference A vs B
# [188] - ok
# [189] - Difference A vs B: [35, 17, 338, 17, 135]
# [189] - ok
# [19] - No Difference A vs B
# [19] - ok
# [190] - No Difference A vs B
# [190] - ok
# [191] - No Difference A vs B
# [191] - ok
# [192] - No Difference A vs B
# [192] - ok
# [193] - Difference A vs B: [0, 0, 1, 0, 0]
# [193] - ok
# [194] - No Difference A vs B
# [194] - ok
# [195] - No Difference A vs B
# [195] - ok
# [196] - Difference A vs B: [1, 1, 68, 9, 64]
# [196] - ok
# [197] - Difference A vs B: [0, 0, 1, 0, 0]
# [197] - ok
# [198] - No Difference A vs B
# [198] - ok
# [199] - No Difference A vs B
# [199] - ok
# [2] - No Difference A vs B
# [2] - Total errors: 2 - [0, -1, -1]
# [20] - No Difference A vs B
# [20] - ok
# [200] - No Difference A vs B
# [200] - ok
# [201] - Difference A vs B: [0, 0, 0, 0, 1]
# [201] - ok
# [202] - Difference A vs B: [0, 0, 1, 0, 0]
# [202] - ok
# [203] - No Difference A vs B
# [203] - ok
# [204] - No Difference A vs B
# [204] - ok
# [205] - No Difference A vs B
# [205] - ok

# %%
ok_or_no_diff = list(set(train_id_ok).union(set(train_id_no_diff)))

# %%
import json

# %%
with open("../data/sealion/dots_ok.json", "w") as ofile:
    ok_filenames = [str(i) + ".jpg" for i in ok_or_no_diff]
    json.dump(ok_filenames, ofile, indent=2, sort_keys=True)

# %%
# !head ../data/sealion/dots_ok.json
# Out:
# [
#   "0.jpg",
#   "1.jpg",
#   "2.jpg",
#   "4.jpg",
#   "5.jpg",
#   "6.jpg",
#   "7.jpg",
#   "8.jpg",
#   "10.jpg",
